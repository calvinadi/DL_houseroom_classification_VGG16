# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ### Dataset source: https://www.kaggle.com/datasets/mikhailma/house-rooms-streets-image-dataset

# %%
import glob as gb

import cv2
import matplotlib.pylab as plt

plt.style.use('ggplot')

# %%
import warnings

warnings.filterwarnings("ignore", message="All log messages before absl::InitializeLog() is called are written to STDERR")
warnings.filterwarnings("ignore", message="Fallback to op-by-op mode because memset node breaks graph update")

# %%
from sklearn.model_selection import train_test_split
import os
import shutil
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
# Out:
# 2024-06-14 05:07:14.640919: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-14 05:07:14.641023: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-14 05:07:14.798352: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    tf.random.set_seed(random_seed)
    
set_random_seed(42)

# %%
# Path gambar
img_path = "/kaggle/input/house-rooms-streets-image-dataset/kaggle_room_street_data/house_data"

input_dir = 'images'
output_dir = 'output'

# Membuat folder output jika belum ada
os.makedirs(output_dir, exist_ok=True)

# %%
# Membuat Folder Kategori
categories = ['bath', 'bed', 'din', 'kitchen', 'living']
for category in categories:
    category_dir = os.path.join(output_dir, category)
    os.makedirs(category_dir, exist_ok=True)

# %%
# Mencari Path Gambar
all_images = gb.glob(img_path + "/*.jpg")

# %%
# Memindahkan Gambar ke Folder Kategori yang Sesuai
for img_path in all_images:
    for category in categories:
        if category in img_path:
            shutil.copy(img_path, os.path.join(output_dir, category, os.path.basename(img_path)))
            break # Pindah ke gambar berikutnya setelah menemukan kategori

# %%
# Buat folder train dan test
train_dir = os.path.join(output_dir, "train")
test_dir = os.path.join(output_dir, "test")
if os.path.exists(train_dir):
    shutil.rmtree(train_dir)
if os.path.exists(test_dir):
    shutil.rmtree(test_dir)
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Split data menjadi 70%train 30%test
for category in categories:
    category_dir = os.path.join(output_dir, category)
    images = os.listdir(category_dir)
    train_images, test_images = train_test_split(images, test_size=0.4, random_state=42)
    
    # Pindahkan gambar-gambar ke dalam folder train dan test
    for img in train_images:
        target_dir = os.path.join(train_dir, category)
        os.makedirs(target_dir, exist_ok=True)
        shutil.move(os.path.join(category_dir, img), os.path.join(target_dir, img))

    for img in test_images:
        target_dir = os.path.join(test_dir, category)
        os.makedirs(target_dir, exist_ok=True)
        shutil.move(os.path.join(category_dir, img), os.path.join(target_dir, img))

# %%
# Cetak jumlah gambar dalam folder train
print("\nJumlah Gambar dalam Folder Train:")
for category in categories:
    train_category_dir = os.path.join(train_dir, category)
    num_train_images = len(os.listdir(train_category_dir))
    print(f"{category}: {num_train_images} gambar")

# Cetak jumlah gambar dalam folder test
print("\nJumlah Gambar dalam Folder Test:")
for category in categories:
    test_category_dir = os.path.join(test_dir, category)
    num_test_images = len(os.listdir(test_category_dir))
    print(f"{category}: {num_test_images} gambar")
# Out:
# Jumlah Gambar dalam Folder Train:
# bath: 363 gambar
# bed: 748 gambar
# din: 694 gambar
# kitchen: 579 gambar
# living: 763 gambar
#
# Jumlah Gambar dalam Folder Test:
# bath: 242 gambar
# bed: 500 gambar
# din: 464 gambar
# kitchen: 386 gambar
# living: 510 gambar

# %%
def convert_to_grayscale(img):
    # Konversi gambar ke grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    return gray

# %%
def apply_clahe(gray_img):
    # Terapkan CLAHE pada gambar grayscale
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    clahe_img = clahe.apply(gray_img)
    
    # Gabungkan kembali ke tiga saluran RGB
    final_img = cv2.merge((clahe_img, clahe_img, clahe_img))
    return final_img

# %%
from keras.preprocessing import image

def preprocess_with_clahe(img):
    # Konversi gambar ke array dengan tipe data uint8
    img_array = image.img_to_array(img, dtype='uint8')
    # Konversi gambar ke grayscale
    gray_img = convert_to_grayscale(img_array)
    # Terapkan CLAHE pada gambar grayscale
    img_clahe = apply_clahe(gray_img)
    # Lakukan preprocess_input VGG16
    img_preprocessed = preprocess_input(img_clahe)
    return img_preprocessed

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.applications.vgg16 import preprocess_input

def visualize_random_images(folder, num_images=1, figsize=(8, 4)):
    categories = os.listdir(folder)
    for category in categories:
        category_dir = os.path.join(folder, category)
        images = os.listdir(category_dir)
        random_images = random.sample(images, num_images)
        print(f"\nContoh Gambar untuk Kategori {category}:")
        for img_file in random_images:
            img_path = os.path.join(category_dir, img_file)
            img = mpimg.imread(img_path)
            img_clahe = preprocess_with_clahe(img)
            
            fig, axes = plt.subplots(1, 2, figsize=figsize)
            axes[0].imshow(img)
            axes[0].set_title('Original Image')
            axes[0].axis("off")
            
            axes[1].imshow(img_clahe)
            axes[1].set_title('CLAHE Image')
            axes[1].axis("off")
            
            plt.show()

print('Train Folder')
visualize_random_images(train_dir, figsize=(8, 4))
print('\nTest Folder')
visualize_random_images(test_dir, figsize=(8, 4))
# Out:
# Train Folder
#
# Contoh Gambar untuk Kategori bath:
# Contoh Gambar untuk Kategori kitchen:
# Contoh Gambar untuk Kategori din:
# Contoh Gambar untuk Kategori living:
# Contoh Gambar untuk Kategori bed:
# Test Folder
#
# Contoh Gambar untuk Kategori bath:
# Contoh Gambar untuk Kategori kitchen:
# Contoh Gambar untuk Kategori din:
# Contoh Gambar untuk Kategori living:
# Contoh Gambar untuk Kategori bed:

# %%
# Membuat objek ImageDataGenerator untuk pelatihan dengan preprocessing CLAHE
train_datagen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=preprocess_with_clahe,
    samplewise_center=True,
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode='nearest'
)

traindata = train_datagen.flow_from_directory(
    directory="./output/train", 
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    shuffle=False)

# Membuat objek ImageDataGenerator untuk pengujian dengan preprocessing CLAHE
test_datagen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=preprocess_with_clahe,
    samplewise_center=True
)

testdata = test_datagen.flow_from_directory(
    directory="./output/test", 
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    shuffle=False)
# Out:
# Found 3147 images belonging to 5 classes.
# Found 2102 images belonging to 5 classes.

# %%
# # Membuat objek ImageDataGenerator untuk pelatihan dengan preprocessing CLAHE
# train_datagen = ImageDataGenerator(
#     rescale=1./255,
#     preprocessing_function=preprocess_with_clahe,
#     samplewise_center=True,
#     rotation_range=10,
#     zoom_range=0.1,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     shear_range=0.1,
#     brightness_range=[0.8, 1.2],
#     horizontal_flip=True,
#     vertical_flip=False,
#     fill_mode='nearest'
# )

# traindata = train_datagen.flow_from_directory(
#     directory="./output/train", 
#     target_size=(224,224), 
#     color_mode="rgb", 
#     class_mode='categorical',
#     shuffle=False)

# # Membuat objek ImageDataGenerator untuk pengujian dengan preprocessing CLAHE
# test_datagen = ImageDataGenerator(
#     rescale=1./255,
#     preprocessing_function=preprocess_with_clahe,
#     samplewise_center=True
# )

# testdata = test_datagen.flow_from_directory(
#     directory="./output/test", 
#     target_size=(224,224), 
#     color_mode="rgb", 
#     class_mode='categorical',
#     shuffle=False)

# %%
testdata.class_indices
# Out:
# {'bath': 0, 'bed': 1, 'din': 2, 'kitchen': 3, 'living': 4}

# %% [markdown]
# ### MODELING

# %%
# VGG16 model (VGG16 is a famous convolution neural net (CNN) architecture 
# invented by Karen Simonyan and Andrew Zisserman in 2014.)

from keras.applications.vgg16 import VGG16

base_model = VGG16(input_shape=(224,224,3), include_top=False, weights='imagenet')

base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# freeze semua layer kecuali 2,3,4 layer dari akhir
for layer in base_model.layers:
    layer.trainable = False
base_model.layers[-2].trainable = True
base_model.layers[-3].trainable = True
base_model.layers[-4].trainable = True

# %%
# base_model.trainable = False

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from keras.regularizers import l2
import tensorflow as tf

# model = Sequential()
# model.add(Input(shape=(224, 224, 3)))
# model.add(base_model)
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(GlobalAveragePooling2D())

# # Adding additional Dense layers with Batch Normalization
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(Dense(256, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(Dense(len(categories), activation='softmax'))

model = Sequential()
model.add(Input(shape=(224, 224, 3)))
model.add(base_model)
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dropout(0.1))
model.add(Dense(512, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.1))
model.add(Dense(256, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.1))
model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.1))
model.add(Dense(len(categories), activation='softmax', kernel_regularizer=l2(0.01)))



# model = Sequential()
# model.add(Input(shape=(224, 224, 3)))
# model.add(base_model)
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Flatten())
# model.add(Dropout(0.2))
# model.add(Dense(256, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(len(categories), activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 7, 7, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,239,365 (65.76 MB)
#  Trainable params: 9,604,101 (36.64 MB)
#  Non-trainable params: 7,635,264 (29.13 MB)

# %%
from tensorflow.keras.optimizers import SGD  # Import SGD optimizer
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.callbacks import ReduceLROnPlateau

#maxpooling 2x2 86.30310893058777%
#maxpooling 3x3 85.60557961463928%
#avgpooling 2x2 85.54216623306274%
#avgpooling 3x3 82.81547427177429%

#maxpool 2x2 + grayscale clahe  87.38110065460205%

device_name = tf.test.gpu_device_name()

np.random.seed(42)

modelpath = './output/bestmodel.keras'

### train the model
with tf.device(device_name):
    
    optimizer = SGD(learning_rate=0.005)
    
    model.compile(
      optimizer=optimizer,
      loss='categorical_crossentropy',
      metrics=['accuracy'])

    # Early stopping for val_accuracy
    early_stopping_acc = EarlyStopping(monitor='val_accuracy', patience=10, 
                                       restore_best_weights=True, mode='max')

    # Early stopping for val_loss
    early_stopping_loss = EarlyStopping(monitor='val_loss', patience=5, 
                                        restore_best_weights=True, mode='min')

    
    # Reduce learning rate when a metric has stopped improving
    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, 
                                  patience=8, min_lr=0.000005, verbose=1)

    
    # Callback ModelCheckpoint untuk menyimpan bobot terbaik
    checkpoint = ModelCheckpoint(
        modelpath,
        monitor='val_accuracy',
        save_best_only=True,  # Hanya menyimpan bobot terbaik
        mode='max',  # Mode untuk membandingkan nilai metrik (misalnya 'max' untuk akurasi)
        verbose=1  # Menampilkan pesan saat menyimpan
    )

    # Train the model
    history = model.fit(x=traindata, validation_data=testdata, epochs=200, 
                        batch_size=32, callbacks=[early_stopping_acc, early_stopping_loss,
                                                  checkpoint,reduce_lr])
# Out:
# Epoch 1/200
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#  1/99 ━━━━━━━━━━━━━━━━━━━━ 1:07:37 41s/step - accuracy: 0.0312 - loss: 16.4452
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1718341737.956575     108 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1718341737.976983     108 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 59/99 ━━━━━━━━━━━━━━━━━━━━ 28s 703ms/step - accuracy: 0.1997 - loss: 16.1901
# W0000 00:00:1718341778.821485     107 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 550ms/step - accuracy: 0.2079 - loss: 16.1137
# W0000 00:00:1718341793.457024     108 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1718341824.165959     107 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.39581, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 128s 883ms/step - accuracy: 0.2081 - loss: 16.1121 - val_accuracy: 0.3958 - val_loss: 15.6588 - learning_rate: 0.0050
# Epoch 2/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.3093 - loss: 15.6156
# Epoch 2: val_accuracy improved from 0.39581 to 0.42341, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 456ms/step - accuracy: 0.3092 - loss: 15.6149 - val_accuracy: 0.4234 - val_loss: 15.2014 - learning_rate: 0.0050
# Epoch 3/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.3830 - loss: 15.1916
# Epoch 3: val_accuracy improved from 0.42341 to 0.46289, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 457ms/step - accuracy: 0.3830 - loss: 15.1907 - val_accuracy: 0.4629 - val_loss: 14.8711 - learning_rate: 0.0050
# Epoch 4/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.5084 - loss: 14.7518
# Epoch 4: val_accuracy improved from 0.46289 to 0.58421, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 455ms/step - accuracy: 0.5084 - loss: 14.7512 - val_accuracy: 0.5842 - val_loss: 14.4063 - learning_rate: 0.0050
# Epoch 5/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.5214 - loss: 14.4627
# Epoch 5: val_accuracy improved from 0.58421 to 0.60228, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 455ms/step - accuracy: 0.5216 - loss: 14.4614 - val_accuracy: 0.6023 - val_loss: 14.1202 - learning_rate: 0.0050
# Epoch 6/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.5948 - loss: 14.0320
# Epoch 6: val_accuracy improved from 0.60228 to 0.64986, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 460ms/step - accuracy: 0.5947 - loss: 14.0315 - val_accuracy: 0.6499 - val_loss: 13.7091 - learning_rate: 0.0050
# Epoch 7/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.6165 - loss: 13.7393
# Epoch 7: val_accuracy improved from 0.64986 to 0.73787, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 452ms/step - accuracy: 0.6165 - loss: 13.7386 - val_accuracy: 0.7379 - val_loss: 13.2832 - learning_rate: 0.0050
# Epoch 8/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.6574 - loss: 13.4011
# Epoch 8: val_accuracy did not improve from 0.73787
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 456ms/step - accuracy: 0.6574 - loss: 13.4004 - val_accuracy: 0.7360 - val_loss: 13.0610 - learning_rate: 0.0050
# Epoch 9/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.7111 - loss: 13.0535
# Epoch 9: val_accuracy improved from 0.73787 to 0.76308, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 456ms/step - accuracy: 0.7109 - loss: 13.0530 - val_accuracy: 0.7631 - val_loss: 12.7446 - learning_rate: 0.0050
# Epoch 10/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.7068 - loss: 12.8139
# Epoch 10: val_accuracy did not improve from 0.76308
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 451ms/step - accuracy: 0.7068 - loss: 12.8132 - val_accuracy: 0.6827 - val_loss: 12.6886 - learning_rate: 0.0050
# Epoch 11/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.7003 - loss: 12.5490
# Epoch 11: val_accuracy improved from 0.76308 to 0.76641, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 453ms/step - accuracy: 0.7005 - loss: 12.5482 - val_accuracy: 0.7664 - val_loss: 12.2707 - learning_rate: 0.0050
# Epoch 12/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.7574 - loss: 12.2246
# Epoch 12: val_accuracy did not improve from 0.76641
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 450ms/step - accuracy: 0.7573 - loss: 12.2243 - val_accuracy: 0.7460 - val_loss: 12.0755 - learning_rate: 0.0050
# Epoch 13/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.7249 - loss: 12.0450
# Epoch 13: val_accuracy did not improve from 0.76641
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 450ms/step - accuracy: 0.7252 - loss: 12.0441 - val_accuracy: 0.7578 - val_loss: 11.8491 - learning_rate: 0.0050
# Epoch 14/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.7645 - loss: 11.7565
# Epoch 14: val_accuracy did not improve from 0.76641
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 450ms/step - accuracy: 0.7646 - loss: 11.7560 - val_accuracy: 0.7203 - val_loss: 11.7210 - learning_rate: 0.0050
# Epoch 15/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.7597 - loss: 11.5520
# Epoch 15: val_accuracy improved from 0.76641 to 0.80304, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 452ms/step - accuracy: 0.7598 - loss: 11.5512 - val_accuracy: 0.8030 - val_loss: 11.3069 - learning_rate: 0.0050
# Epoch 16/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.7654 - loss: 11.3415
# Epoch 16: val_accuracy did not improve from 0.80304
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 453ms/step - accuracy: 0.7657 - loss: 11.3405 - val_accuracy: 0.7907 - val_loss: 11.1326 - learning_rate: 0.0050
# Epoch 17/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.7981 - loss: 11.0394
# Epoch 17: val_accuracy did not improve from 0.80304
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 447ms/step - accuracy: 0.7980 - loss: 11.0392 - val_accuracy: 0.8030 - val_loss: 10.8961 - learning_rate: 0.0050
# Epoch 18/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.7905 - loss: 10.8311
# Epoch 18: val_accuracy did not improve from 0.80304
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 455ms/step - accuracy: 0.7906 - loss: 10.8306 - val_accuracy: 0.8016 - val_loss: 10.7040 - learning_rate: 0.0050
# Epoch 19/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.8348 - loss: 10.5546
# Epoch 19: val_accuracy did not improve from 0.80304
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 450ms/step - accuracy: 0.8346 - loss: 10.5545 - val_accuracy: 0.7821 - val_loss: 10.5540 - learning_rate: 0.0050
# Epoch 20/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.8297 - loss: 10.3631
# Epoch 20: val_accuracy improved from 0.80304 to 0.82398, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 83s 458ms/step - accuracy: 0.8296 - loss: 10.3630 - val_accuracy: 0.8240 - val_loss: 10.2288 - learning_rate: 0.0050
# Epoch 21/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.8266 - loss: 10.1731
# Epoch 21: val_accuracy did not improve from 0.82398
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 450ms/step - accuracy: 0.8265 - loss: 10.1727 - val_accuracy: 0.7735 - val_loss: 10.2024 - learning_rate: 0.0050
# Epoch 22/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.8147 - loss: 9.9989
# Epoch 22: val_accuracy did not improve from 0.82398
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 451ms/step - accuracy: 0.8148 - loss: 9.9984 - val_accuracy: 0.8187 - val_loss: 9.8962 - learning_rate: 0.0050
# Epoch 23/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.8349 - loss: 9.7937
# Epoch 23: val_accuracy improved from 0.82398 to 0.82445, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 452ms/step - accuracy: 0.8349 - loss: 9.7931 - val_accuracy: 0.8245 - val_loss: 9.6870 - learning_rate: 0.0050
# Epoch 24/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.8482 - loss: 9.5718
# Epoch 24: val_accuracy did not improve from 0.82445
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 453ms/step - accuracy: 0.8482 - loss: 9.5715 - val_accuracy: 0.7807 - val_loss: 9.6399 - learning_rate: 0.0050
# Epoch 25/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.8549 - loss: 9.4085
# Epoch 25: val_accuracy did not improve from 0.82445
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 445ms/step - accuracy: 0.8549 - loss: 9.4080 - val_accuracy: 0.8235 - val_loss: 9.3555 - learning_rate: 0.0050
# Epoch 26/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.8420 - loss: 9.2262
# Epoch 26: val_accuracy improved from 0.82445 to 0.82969, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 456ms/step - accuracy: 0.8421 - loss: 9.2258 - val_accuracy: 0.8297 - val_loss: 9.1670 - learning_rate: 0.0050
# Epoch 27/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.8688 - loss: 8.9876
# Epoch 27: val_accuracy did not improve from 0.82969
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 450ms/step - accuracy: 0.8687 - loss: 8.9876 - val_accuracy: 0.7978 - val_loss: 9.0947 - learning_rate: 0.0050
# Epoch 28/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.8634 - loss: 8.8518
# Epoch 28: val_accuracy did not improve from 0.82969
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 452ms/step - accuracy: 0.8634 - loss: 8.8514 - val_accuracy: 0.8164 - val_loss: 8.8695 - learning_rate: 0.0050
# Epoch 29/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.8684 - loss: 8.6721
# Epoch 29: val_accuracy improved from 0.82969 to 0.84063, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 455ms/step - accuracy: 0.8684 - loss: 8.6717 - val_accuracy: 0.8406 - val_loss: 8.6442 - learning_rate: 0.0050
# Epoch 30/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.8725 - loss: 8.5002
# Epoch 30: val_accuracy improved from 0.84063 to 0.84539, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 455ms/step - accuracy: 0.8726 - loss: 8.4998 - val_accuracy: 0.8454 - val_loss: 8.4814 - learning_rate: 0.0050
# Epoch 31/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.8611 - loss: 8.3684
# Epoch 31: val_accuracy did not improve from 0.84539
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 447ms/step - accuracy: 0.8612 - loss: 8.3678 - val_accuracy: 0.8335 - val_loss: 8.3755 - learning_rate: 0.0050
# Epoch 32/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.8758 - loss: 8.1815
# Epoch 32: val_accuracy did not improve from 0.84539
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 451ms/step - accuracy: 0.8758 - loss: 8.1811 - val_accuracy: 0.8363 - val_loss: 8.1920 - learning_rate: 0.0050
# Epoch 33/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.8863 - loss: 7.9984
# Epoch 33: val_accuracy improved from 0.84539 to 0.84824, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 453ms/step - accuracy: 0.8863 - loss: 7.9981 - val_accuracy: 0.8482 - val_loss: 7.9954 - learning_rate: 0.0050
# Epoch 34/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.8861 - loss: 7.8638
# Epoch 34: val_accuracy did not improve from 0.84824
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 454ms/step - accuracy: 0.8861 - loss: 7.8634 - val_accuracy: 0.8135 - val_loss: 8.0021 - learning_rate: 0.0050
# Epoch 35/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.8867 - loss: 7.7131
# Epoch 35: val_accuracy did not improve from 0.84824
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 450ms/step - accuracy: 0.8867 - loss: 7.7127 - val_accuracy: 0.8454 - val_loss: 7.7304 - learning_rate: 0.0050
# Epoch 36/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.8818 - loss: 7.5681
# Epoch 36: val_accuracy did not improve from 0.84824
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 453ms/step - accuracy: 0.8818 - loss: 7.5676 - val_accuracy: 0.8344 - val_loss: 7.6308 - learning_rate: 0.0050
# Epoch 37/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.8954 - loss: 7.4292
# Epoch 37: val_accuracy improved from 0.84824 to 0.85014, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 456ms/step - accuracy: 0.8954 - loss: 7.4287 - val_accuracy: 0.8501 - val_loss: 7.4175 - learning_rate: 0.0050
# Epoch 38/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.9015 - loss: 7.2475
# Epoch 38: val_accuracy improved from 0.85014 to 0.85252, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 452ms/step - accuracy: 0.9015 - loss: 7.2473 - val_accuracy: 0.8525 - val_loss: 7.3008 - learning_rate: 0.0050
# Epoch 39/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.9059 - loss: 7.1002
# Epoch 39: val_accuracy did not improve from 0.85252
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 445ms/step - accuracy: 0.9059 - loss: 7.1000 - val_accuracy: 0.8440 - val_loss: 7.2036 - learning_rate: 0.0050
# Epoch 40/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9029 - loss: 6.9743
# Epoch 40: val_accuracy did not improve from 0.85252
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 452ms/step - accuracy: 0.9029 - loss: 6.9740 - val_accuracy: 0.8440 - val_loss: 7.0722 - learning_rate: 0.0050
# Epoch 41/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.9098 - loss: 6.8384
# Epoch 41: val_accuracy improved from 0.85252 to 0.85300, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 452ms/step - accuracy: 0.9098 - loss: 6.8382 - val_accuracy: 0.8530 - val_loss: 6.9226 - learning_rate: 0.0050
# Epoch 42/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.9105 - loss: 6.7202
# Epoch 42: val_accuracy did not improve from 0.85300
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 455ms/step - accuracy: 0.9106 - loss: 6.7198 - val_accuracy: 0.8511 - val_loss: 6.8041 - learning_rate: 0.0050
# Epoch 43/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9260 - loss: 6.5510
# Epoch 43: val_accuracy did not improve from 0.85300
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 451ms/step - accuracy: 0.9259 - loss: 6.5507 - val_accuracy: 0.8183 - val_loss: 6.7941 - learning_rate: 0.0050
# Epoch 44/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9163 - loss: 6.4364
# Epoch 44: val_accuracy improved from 0.85300 to 0.85347, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 457ms/step - accuracy: 0.9162 - loss: 6.4364 - val_accuracy: 0.8535 - val_loss: 6.5502 - learning_rate: 0.0050
# Epoch 45/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9316 - loss: 6.3045
# Epoch 45: val_accuracy did not improve from 0.85347
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 451ms/step - accuracy: 0.9315 - loss: 6.3043 - val_accuracy: 0.8392 - val_loss: 6.4957 - learning_rate: 0.0050
# Epoch 46/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.9182 - loss: 6.1978
# Epoch 46: val_accuracy did not improve from 0.85347
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 448ms/step - accuracy: 0.9182 - loss: 6.1976 - val_accuracy: 0.8473 - val_loss: 6.3305 - learning_rate: 0.0050
# Epoch 47/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.9119 - loss: 6.0910
# Epoch 47: val_accuracy improved from 0.85347 to 0.85823, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 449ms/step - accuracy: 0.9120 - loss: 6.0905 - val_accuracy: 0.8582 - val_loss: 6.2165 - learning_rate: 0.0050
# Epoch 48/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.9302 - loss: 5.9510
# Epoch 48: val_accuracy did not improve from 0.85823
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 453ms/step - accuracy: 0.9301 - loss: 5.9506 - val_accuracy: 0.8368 - val_loss: 6.1713 - learning_rate: 0.0050
# Epoch 49/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.9355 - loss: 5.8152
# Epoch 49: val_accuracy improved from 0.85823 to 0.85871, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 451ms/step - accuracy: 0.9354 - loss: 5.8152 - val_accuracy: 0.8587 - val_loss: 5.9693 - learning_rate: 0.0050
# Epoch 50/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.9396 - loss: 5.7018
# Epoch 50: val_accuracy did not improve from 0.85871
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 453ms/step - accuracy: 0.9396 - loss: 5.7016 - val_accuracy: 0.8454 - val_loss: 5.9554 - learning_rate: 0.0050
# Epoch 51/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.9284 - loss: 5.6101
# Epoch 51: val_accuracy did not improve from 0.85871
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 451ms/step - accuracy: 0.9284 - loss: 5.6099 - val_accuracy: 0.8563 - val_loss: 5.7862 - learning_rate: 0.0050
# Epoch 52/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.9350 - loss: 5.5114
# Epoch 52: val_accuracy improved from 0.85871 to 0.86156, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 453ms/step - accuracy: 0.9350 - loss: 5.5112 - val_accuracy: 0.8616 - val_loss: 5.6608 - learning_rate: 0.0050
# Epoch 53/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9392 - loss: 5.3839
# Epoch 53: val_accuracy did not improve from 0.86156
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 452ms/step - accuracy: 0.9392 - loss: 5.3837 - val_accuracy: 0.8506 - val_loss: 5.6345 - learning_rate: 0.0050
# Epoch 54/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.9276 - loss: 5.3104
# Epoch 54: val_accuracy did not improve from 0.86156
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 448ms/step - accuracy: 0.9276 - loss: 5.3100 - val_accuracy: 0.8283 - val_loss: 5.6103 - learning_rate: 0.0050
# Epoch 55/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.9380 - loss: 5.1908
# Epoch 55: val_accuracy did not improve from 0.86156
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 449ms/step - accuracy: 0.9380 - loss: 5.1905 - val_accuracy: 0.8563 - val_loss: 5.3850 - learning_rate: 0.0050
# Epoch 56/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.9507 - loss: 5.0813
# Epoch 56: val_accuracy did not improve from 0.86156
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 448ms/step - accuracy: 0.9507 - loss: 5.0811 - val_accuracy: 0.8487 - val_loss: 5.3563 - learning_rate: 0.0050
# Epoch 57/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9451 - loss: 4.9835
# Epoch 57: val_accuracy did not improve from 0.86156
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 452ms/step - accuracy: 0.9451 - loss: 4.9833 - val_accuracy: 0.8578 - val_loss: 5.2415 - learning_rate: 0.0050
# Epoch 58/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9518 - loss: 4.8830
# Epoch 58: val_accuracy did not improve from 0.86156
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 451ms/step - accuracy: 0.9517 - loss: 4.8830 - val_accuracy: 0.8587 - val_loss: 5.1269 - learning_rate: 0.0050
# Epoch 59/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9426 - loss: 4.8223
# Epoch 59: val_accuracy did not improve from 0.86156
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 455ms/step - accuracy: 0.9426 - loss: 4.8219 - val_accuracy: 0.8501 - val_loss: 5.0996 - learning_rate: 0.0050
# Epoch 60/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.9362 - loss: 4.7424
# Epoch 60: val_accuracy did not improve from 0.86156
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 0.0004999999888241291.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 449ms/step - accuracy: 0.9363 - loss: 4.7420 - val_accuracy: 0.8520 - val_loss: 4.9806 - learning_rate: 0.0050
# Epoch 61/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9552 - loss: 4.6309
# Epoch 61: val_accuracy improved from 0.86156 to 0.87012, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 454ms/step - accuracy: 0.9553 - loss: 4.6307 - val_accuracy: 0.8701 - val_loss: 4.9034 - learning_rate: 5.0000e-04
# Epoch 62/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9619 - loss: 4.6032
# Epoch 62: val_accuracy improved from 0.87012 to 0.87203, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 454ms/step - accuracy: 0.9620 - loss: 4.6030 - val_accuracy: 0.8720 - val_loss: 4.9002 - learning_rate: 5.0000e-04
# Epoch 63/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.9743 - loss: 4.5645
# Epoch 63: val_accuracy did not improve from 0.87203
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 446ms/step - accuracy: 0.9743 - loss: 4.5646 - val_accuracy: 0.8706 - val_loss: 4.8969 - learning_rate: 5.0000e-04
# Epoch 64/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.9713 - loss: 4.5648
# Epoch 64: val_accuracy improved from 0.87203 to 0.87298, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 451ms/step - accuracy: 0.9712 - loss: 4.5647 - val_accuracy: 0.8730 - val_loss: 4.8910 - learning_rate: 5.0000e-04
# Epoch 65/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.9704 - loss: 4.5568
# Epoch 65: val_accuracy did not improve from 0.87298
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 449ms/step - accuracy: 0.9704 - loss: 4.5568 - val_accuracy: 0.8716 - val_loss: 4.8787 - learning_rate: 5.0000e-04
# Epoch 66/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9710 - loss: 4.5440
# Epoch 66: val_accuracy improved from 0.87298 to 0.87345, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 458ms/step - accuracy: 0.9710 - loss: 4.5440 - val_accuracy: 0.8735 - val_loss: 4.8726 - learning_rate: 5.0000e-04
# Epoch 67/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9684 - loss: 4.5458
# Epoch 67: val_accuracy did not improve from 0.87345
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 451ms/step - accuracy: 0.9684 - loss: 4.5457 - val_accuracy: 0.8725 - val_loss: 4.8639 - learning_rate: 5.0000e-04
# Epoch 68/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.9746 - loss: 4.5232
# Epoch 68: val_accuracy did not improve from 0.87345
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 452ms/step - accuracy: 0.9746 - loss: 4.5232 - val_accuracy: 0.8730 - val_loss: 4.8580 - learning_rate: 5.0000e-04
# Epoch 69/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9757 - loss: 4.5051
# Epoch 69: val_accuracy did not improve from 0.87345
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 452ms/step - accuracy: 0.9757 - loss: 4.5051 - val_accuracy: 0.8687 - val_loss: 4.8510 - learning_rate: 5.0000e-04
# Epoch 70/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9695 - loss: 4.5100
# Epoch 70: val_accuracy improved from 0.87345 to 0.87393, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 454ms/step - accuracy: 0.9695 - loss: 4.5100 - val_accuracy: 0.8739 - val_loss: 4.8405 - learning_rate: 5.0000e-04
# Epoch 71/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9725 - loss: 4.4906
# Epoch 71: val_accuracy did not improve from 0.87393
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 452ms/step - accuracy: 0.9725 - loss: 4.4906 - val_accuracy: 0.8725 - val_loss: 4.8317 - learning_rate: 5.0000e-04
# Epoch 72/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9674 - loss: 4.4983
# Epoch 72: val_accuracy did not improve from 0.87393
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 452ms/step - accuracy: 0.9674 - loss: 4.4982 - val_accuracy: 0.8711 - val_loss: 4.8253 - learning_rate: 5.0000e-04
# Epoch 73/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.9703 - loss: 4.4776
# Epoch 73: val_accuracy did not improve from 0.87393
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 449ms/step - accuracy: 0.9703 - loss: 4.4776 - val_accuracy: 0.8716 - val_loss: 4.8192 - learning_rate: 5.0000e-04
# Epoch 74/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.9808 - loss: 4.4581
# Epoch 74: val_accuracy did not improve from 0.87393
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 449ms/step - accuracy: 0.9807 - loss: 4.4582 - val_accuracy: 0.8739 - val_loss: 4.8103 - learning_rate: 5.0000e-04
# Epoch 75/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.9763 - loss: 4.4553
# Epoch 75: val_accuracy did not improve from 0.87393
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 450ms/step - accuracy: 0.9762 - loss: 4.4553 - val_accuracy: 0.8735 - val_loss: 4.8009 - learning_rate: 5.0000e-04
# Epoch 76/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.9728 - loss: 4.4552
# Epoch 76: val_accuracy improved from 0.87393 to 0.87441, saving model to ./output/bestmodel.keras
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 450ms/step - accuracy: 0.9728 - loss: 4.4551 - val_accuracy: 0.8744 - val_loss: 4.7943 - learning_rate: 5.0000e-04
# Epoch 77/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9725 - loss: 4.4494
# Epoch 77: val_accuracy did not improve from 0.87441
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 450ms/step - accuracy: 0.9725 - loss: 4.4494 - val_accuracy: 0.8725 - val_loss: 4.7910 - learning_rate: 5.0000e-04
# Epoch 78/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.9693 - loss: 4.4391
# Epoch 78: val_accuracy did not improve from 0.87441
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 449ms/step - accuracy: 0.9693 - loss: 4.4390 - val_accuracy: 0.8739 - val_loss: 4.7803 - learning_rate: 5.0000e-04
# Epoch 79/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.9729 - loss: 4.4282
# Epoch 79: val_accuracy did not improve from 0.87441
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 444ms/step - accuracy: 0.9729 - loss: 4.4282 - val_accuracy: 0.8716 - val_loss: 4.7706 - learning_rate: 5.0000e-04
# Epoch 80/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.9653 - loss: 4.4347
# Epoch 80: val_accuracy did not improve from 0.87441
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 48s 453ms/step - accuracy: 0.9654 - loss: 4.4346 - val_accuracy: 0.8706 - val_loss: 4.7658 - learning_rate: 5.0000e-04
# Epoch 81/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.9752 - loss: 4.4016
# Epoch 81: val_accuracy did not improve from 0.87441
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 450ms/step - accuracy: 0.9751 - loss: 4.4016 - val_accuracy: 0.8701 - val_loss: 4.7550 - learning_rate: 5.0000e-04
# Epoch 82/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.9722 - loss: 4.3949
# Epoch 82: val_accuracy did not improve from 0.87441
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 447ms/step - accuracy: 0.9721 - loss: 4.3950 - val_accuracy: 0.8711 - val_loss: 4.7466 - learning_rate: 5.0000e-04
# Epoch 83/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9734 - loss: 4.3994
# Epoch 83: val_accuracy did not improve from 0.87441
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 451ms/step - accuracy: 0.9734 - loss: 4.3993 - val_accuracy: 0.8730 - val_loss: 4.7399 - learning_rate: 5.0000e-04
# Epoch 84/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.9753 - loss: 4.3767
# Epoch 84: val_accuracy did not improve from 0.87441
#
# Epoch 84: ReduceLROnPlateau reducing learning rate to 4.9999996554106475e-05.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 450ms/step - accuracy: 0.9753 - loss: 4.3768 - val_accuracy: 0.8677 - val_loss: 4.7307 - learning_rate: 5.0000e-04
# Epoch 85/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.9773 - loss: 4.3678
# Epoch 85: val_accuracy did not improve from 0.87441
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 449ms/step - accuracy: 0.9773 - loss: 4.3678 - val_accuracy: 0.8701 - val_loss: 4.7294 - learning_rate: 5.0000e-05
# Epoch 86/200
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.9761 - loss: 4.3617
# Epoch 86: val_accuracy did not improve from 0.87441
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 47s 443ms/step - accuracy: 0.9761 - loss: 4.3617 - val_accuracy: 0.8701 - val_loss: 4.7289 - learning_rate: 5.0000e-05

# %%
#Test the model with the test set

model.evaluate(testdata)
# Out:
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 9s 133ms/step - accuracy: 0.8946 - loss: 4.6303
# [4.72888708114624, 0.8701236844062805]

# %%
# Visualize the model

plt.plot(history.history['accuracy'], marker='o')
plt.plot(history.history['val_accuracy'], marker='o')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'], marker='o')
plt.plot(history.history['val_loss'], marker='o')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# Prediksi label kelas menggunakan model terhadap data uji
predictions = model.predict(testdata)
predicted_classes = np.argmax(predictions, axis=1)

# Ambil label sebenarnya dari data uji
true_classes = testdata.labels

# Dapatkan nama kelas
class_labels = list(testdata.class_indices.keys())

# Buat classification matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Print classification matrix
print("Classification Matrix:")
print(cm)

# Print classification report
print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))
# Out:
#  2/66 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step
# W0000 00:00:1718345897.457505     107 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step
# Classification Matrix:
# [[216   4   1  15   6]
#  [  8 461   2   2  27]
#  [  3   2 405  27  27]
#  [ 14   1  36 321  14]
#  [  4  26  43  11 426]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         bath       0.88      0.89      0.89       242
#          bed       0.93      0.92      0.93       500
#          din       0.83      0.87      0.85       464
#      kitchen       0.85      0.83      0.84       386
#       living       0.85      0.84      0.84       510
#
#     accuracy                           0.87      2102
#    macro avg       0.87      0.87      0.87      2102
# weighted avg       0.87      0.87      0.87      2102
# W0000 00:00:1718345906.522089     105 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update

# %% [markdown]
# Accuracy adalah rasio dari jumlah prediksi yang benar (true predictions) dibagi dengan jumlah total instance dalam dataset.

# %% [markdown]
# Precision mengukur seberapa akurat model dalam memprediksi kelas positif. Ini dihitung sebagai rasio dari true positive (TP) dibagi oleh jumlah true positive dan false positive (FP).

# %% [markdown]
#  Recall mengukur seberapa baik model dalam menemukan semua instance yang benar dari kelas yang diinginkan. Ini dihitung sebagai rasio dari true positive (TP) dibagi oleh jumlah true positive dan false negative (FN).

# %% [markdown]
# F1-score adalah rata-rata harmonik dari precision dan recall. Ini memberikan keseimbangan antara precision dan recall.
