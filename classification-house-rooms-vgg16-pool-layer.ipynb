# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ### Dataset source: https://www.kaggle.com/datasets/mikhailma/house-rooms-streets-image-dataset

# %%
import glob as gb

import cv2
import matplotlib.pylab as plt

plt.style.use('ggplot')

# %%
import warnings

warnings.filterwarnings("ignore", message="All log messages before absl::InitializeLog() is called are written to STDERR")
warnings.filterwarnings("ignore", message="Fallback to op-by-op mode because memset node breaks graph update")

# %%
from sklearn.model_selection import train_test_split
import os
import shutil
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# 2024-06-10 12:56:12.109235: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-10 12:56:12.109304: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-10 12:56:12.110943: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Path gambar
img_path = "/kaggle/input/house-rooms-streets-image-dataset/kaggle_room_street_data/house_data"

input_dir = 'images'
output_dir = 'output'

# Membuat folder output jika belum ada
os.makedirs(output_dir, exist_ok=True)

# %%
# Membuat Folder Kategori
categories = ['bath', 'bed', 'din', 'kitchen', 'living']
for category in categories:
    category_dir = os.path.join(output_dir, category)
    os.makedirs(category_dir, exist_ok=True)

# %%
# Mencari Path Gambar
all_images = gb.glob(img_path + "/*.jpg")

# %%
# Memindahkan Gambar ke Folder Kategori yang Sesuai
for img_path in all_images:
    for category in categories:
        if category in img_path:
            shutil.copy(img_path, os.path.join(output_dir, category, os.path.basename(img_path)))
            break # Pindah ke gambar berikutnya setelah menemukan kategori

# %%
# Buat folder train dan test
train_dir = os.path.join(output_dir, "train")
test_dir = os.path.join(output_dir, "test")
if os.path.exists(train_dir):
    shutil.rmtree(train_dir)
if os.path.exists(test_dir):
    shutil.rmtree(test_dir)
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Split data menjadi 70%train 30%test
for category in categories:
    category_dir = os.path.join(output_dir, category)
    images = os.listdir(category_dir)
    train_images, test_images = train_test_split(images, test_size=0.3, random_state=42)
    
    # Pindahkan gambar-gambar ke dalam folder train dan test
    for img in train_images:
        target_dir = os.path.join(train_dir, category)
        os.makedirs(target_dir, exist_ok=True)
        shutil.move(os.path.join(category_dir, img), os.path.join(target_dir, img))

    for img in test_images:
        target_dir = os.path.join(test_dir, category)
        os.makedirs(target_dir, exist_ok=True)
        shutil.move(os.path.join(category_dir, img), os.path.join(target_dir, img))

# %%
# Cetak jumlah gambar dalam folder train
print("\nJumlah Gambar dalam Folder Train:")
for category in categories:
    train_category_dir = os.path.join(train_dir, category)
    num_train_images = len(os.listdir(train_category_dir))
    print(f"{category}: {num_train_images} gambar")

# Cetak jumlah gambar dalam folder test
print("\nJumlah Gambar dalam Folder Test:")
for category in categories:
    test_category_dir = os.path.join(test_dir, category)
    num_test_images = len(os.listdir(test_category_dir))
    print(f"{category}: {num_test_images} gambar")
# Out:
# Jumlah Gambar dalam Folder Train:
# bath: 423 gambar
# bed: 873 gambar
# din: 810 gambar
# kitchen: 675 gambar
# living: 891 gambar
#
# Jumlah Gambar dalam Folder Test:
# bath: 182 gambar
# bed: 375 gambar
# din: 348 gambar
# kitchen: 290 gambar
# living: 382 gambar

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def visualize_random_images(folder, num_images=1, figsize=(4, 4)):
    categories = os.listdir(folder)
    for category in categories:
        category_dir = os.path.join(folder, category)
        images = os.listdir(category_dir)
        random_images = random.sample(images, num_images)
        print(f"\nContoh Gambar untuk Kategori {category}:")
        for img_file in random_images:
            img_path = os.path.join(category_dir, img_file)
            img = mpimg.imread(img_path)
            plt.figure(figsize=figsize)
            plt.imshow(img)
            plt.axis("off")
            plt.show()

print('Train Folder')
visualize_random_images(train_dir, figsize=(2, 2))
print('\nTest Folder')
visualize_random_images(test_dir, figsize=(2, 2))
# Out:
# Train Folder
#
# Contoh Gambar untuk Kategori bath:
# Contoh Gambar untuk Kategori living:
# Contoh Gambar untuk Kategori bed:
# Contoh Gambar untuk Kategori din:
# Contoh Gambar untuk Kategori kitchen:
# Test Folder
#
# Contoh Gambar untuk Kategori bath:
# Contoh Gambar untuk Kategori living:
# Contoh Gambar untuk Kategori bed:
# Contoh Gambar untuk Kategori din:
# Contoh Gambar untuk Kategori kitchen:

# %%
from keras.applications.vgg16 import preprocess_input


np.random.seed(42)
trdata = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=preprocess_input,
    samplewise_center=True,  # set each sample mean to 0
    rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
    zoom_range=0.1,  # Randomly zoom image
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
    horizontal_flip=True,  # randomly flip images
    vertical_flip=False,
)

traindata = trdata.flow_from_directory(
    directory="./output/train", 
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    shuffle=False)

tsdata = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=preprocess_input,
    samplewise_center=True
)

testdata = tsdata.flow_from_directory(
    directory="./output/test", 
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    shuffle=False)
# Out:
# Found 3672 images belonging to 5 classes.
# Found 1577 images belonging to 5 classes.

# %%
testdata.class_indices
# Out:
# {'bath': 0, 'bed': 1, 'din': 2, 'kitchen': 3, 'living': 4}

# %% [markdown]
# ### MODELING

# %%
# VGG16 model (VGG16 is a famous convolution neural net (CNN) architecture 
# invented by Karen Simonyan and Andrew Zisserman in 2014.)

from keras.applications.vgg16 import VGG16

base_model = VGG16(input_shape=(224,224,3), include_top=False, weights='imagenet')

base_model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# freeze semua layer kecuali 2,3,4 layer dari akhir
for layer in base_model.layers:
    layer.trainable = False
base_model.layers[-2].trainable = True
base_model.layers[-3].trainable = True
base_model.layers[-4].trainable = True

# %%
# base_model.trainable = False

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
import tensorflow as tf

device_name = tf.test.gpu_device_name()

np.random.seed(42)

model = Sequential()
model.add(Input(shape=(224, 224, 3)))
model.add(base_model)
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(len(categories), activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 7, 7, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,895,877 (60.64 MB)
#  Trainable params: 8,260,613 (31.51 MB)
#  Non-trainable params: 7,635,264 (29.13 MB)

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import SGD  # Import SGD optimizer
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

#maxpooling 2x2 86.30310893058777%
#maxpooling 3x3 85.60557961463928%
#avgpooling 2x2 85.54216623306274%
#avgpooling 3x3 82.81547427177429%

device_name = tf.test.gpu_device_name()

modelpath = './output/bestmodel.keras'

np.random.seed(42)

### train the model
with tf.device(device_name):
    
    optimizer = SGD(learning_rate=0.005)
    
    model.compile(
      optimizer=optimizer,
      loss='categorical_crossentropy',
      metrics=['accuracy'])

    # Callback EarlyStopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    
    # Callback ModelCheckpoint untuk menyimpan bobot terbaik
    checkpoint = ModelCheckpoint(
        modelpath,
        monitor='val_accuracy',
        save_best_only=True,  # Hanya menyimpan bobot terbaik
        mode='max',  # Mode untuk membandingkan nilai metrik (misalnya 'max' untuk akurasi)
        verbose=1  # Menampilkan pesan saat menyimpan
    )

    # Train the model
    history = model.fit(x=traindata, validation_data=testdata, epochs=100, batch_size=32, callbacks=[early_stopping,checkpoint])
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   1/115 ━━━━━━━━━━━━━━━━━━━━ 1:22:02 43s/step - accuracy: 0.0312 - loss: 2.6343
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1718024231.759941    2750 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1718024231.779125    2750 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#  36/115 ━━━━━━━━━━━━━━━━━━━━ 1:30 1s/step - accuracy: 0.2326 - loss: 2.5310
# W0000 00:00:1718024271.896646    2749 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.2374 - loss: 2.0280
# W0000 00:00:1718024296.417809    2749 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.38174, saving model to ./output/bestmodel.keras
# W0000 00:00:1718024315.255212    2750 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 127s 734ms/step - accuracy: 0.2375 - loss: 2.0253 - val_accuracy: 0.3817 - val_loss: 1.4885
# Epoch 2/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.3600 - loss: 1.4622
# Epoch 2: val_accuracy improved from 0.38174 to 0.54090, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 365ms/step - accuracy: 0.3599 - loss: 1.4623 - val_accuracy: 0.5409 - val_loss: 1.2665
# Epoch 3/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.4472 - loss: 1.3462
# Epoch 3: val_accuracy did not improve from 0.54090
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 363ms/step - accuracy: 0.4475 - loss: 1.3457 - val_accuracy: 0.5396 - val_loss: 1.0956
# Epoch 4/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.5175 - loss: 1.1636
# Epoch 4: val_accuracy improved from 0.54090 to 0.67026, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 365ms/step - accuracy: 0.5177 - loss: 1.1633 - val_accuracy: 0.6703 - val_loss: 0.8948
# Epoch 5/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.6185 - loss: 0.9504
# Epoch 5: val_accuracy did not improve from 0.67026
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 360ms/step - accuracy: 0.6184 - loss: 0.9506 - val_accuracy: 0.6265 - val_loss: 1.0161
# Epoch 6/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.6202 - loss: 0.9714
# Epoch 6: val_accuracy improved from 0.67026 to 0.68548, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 365ms/step - accuracy: 0.6204 - loss: 0.9710 - val_accuracy: 0.6855 - val_loss: 0.8198
# Epoch 7/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.6590 - loss: 0.8427
# Epoch 7: val_accuracy improved from 0.68548 to 0.70704, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 365ms/step - accuracy: 0.6591 - loss: 0.8427 - val_accuracy: 0.7070 - val_loss: 0.7506
# Epoch 8/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.6842 - loss: 0.8151
# Epoch 8: val_accuracy did not improve from 0.70704
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 364ms/step - accuracy: 0.6843 - loss: 0.8148 - val_accuracy: 0.6937 - val_loss: 0.8111
# Epoch 9/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.6998 - loss: 0.7559
# Epoch 9: val_accuracy improved from 0.70704 to 0.76665, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 364ms/step - accuracy: 0.7000 - loss: 0.7556 - val_accuracy: 0.7666 - val_loss: 0.6185
# Epoch 10/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.7614 - loss: 0.6399
# Epoch 10: val_accuracy did not improve from 0.76665
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 361ms/step - accuracy: 0.7613 - loss: 0.6402 - val_accuracy: 0.7559 - val_loss: 0.6569
# Epoch 11/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.7396 - loss: 0.6692
# Epoch 11: val_accuracy improved from 0.76665 to 0.78377, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 45s 369ms/step - accuracy: 0.7397 - loss: 0.6690 - val_accuracy: 0.7838 - val_loss: 0.6100
# Epoch 12/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.7743 - loss: 0.5945
# Epoch 12: val_accuracy did not improve from 0.78377
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 362ms/step - accuracy: 0.7743 - loss: 0.5945 - val_accuracy: 0.6867 - val_loss: 0.8361
# Epoch 13/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.7652 - loss: 0.6049
# Epoch 13: val_accuracy improved from 0.78377 to 0.80152, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 366ms/step - accuracy: 0.7653 - loss: 0.6048 - val_accuracy: 0.8015 - val_loss: 0.5409
# Epoch 14/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.7935 - loss: 0.5578
# Epoch 14: val_accuracy did not improve from 0.80152
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 361ms/step - accuracy: 0.7935 - loss: 0.5578 - val_accuracy: 0.7901 - val_loss: 0.5603
# Epoch 15/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.7926 - loss: 0.5537
# Epoch 15: val_accuracy did not improve from 0.80152
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 363ms/step - accuracy: 0.7926 - loss: 0.5536 - val_accuracy: 0.7876 - val_loss: 0.5738
# Epoch 16/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.8181 - loss: 0.4769
# Epoch 16: val_accuracy improved from 0.80152 to 0.81357, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 45s 368ms/step - accuracy: 0.8181 - loss: 0.4770 - val_accuracy: 0.8136 - val_loss: 0.5157
# Epoch 17/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.8236 - loss: 0.4795
# Epoch 17: val_accuracy did not improve from 0.81357
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 359ms/step - accuracy: 0.8236 - loss: 0.4795 - val_accuracy: 0.7876 - val_loss: 0.6036
# Epoch 18/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.8152 - loss: 0.4698
# Epoch 18: val_accuracy improved from 0.81357 to 0.82118, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 364ms/step - accuracy: 0.8153 - loss: 0.4698 - val_accuracy: 0.8212 - val_loss: 0.5105
# Epoch 19/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.8412 - loss: 0.4432
# Epoch 19: val_accuracy did not improve from 0.82118
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 362ms/step - accuracy: 0.8412 - loss: 0.4430 - val_accuracy: 0.7660 - val_loss: 0.6469
# Epoch 20/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.8384 - loss: 0.4192
# Epoch 20: val_accuracy improved from 0.82118 to 0.84211, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 362ms/step - accuracy: 0.8384 - loss: 0.4191 - val_accuracy: 0.8421 - val_loss: 0.4709
# Epoch 21/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.8630 - loss: 0.3939
# Epoch 21: val_accuracy did not improve from 0.84211
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 361ms/step - accuracy: 0.8629 - loss: 0.3938 - val_accuracy: 0.8117 - val_loss: 0.5750
# Epoch 22/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.8720 - loss: 0.3475
# Epoch 22: val_accuracy did not improve from 0.84211
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 361ms/step - accuracy: 0.8720 - loss: 0.3477 - val_accuracy: 0.8237 - val_loss: 0.5009
# Epoch 23/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.8786 - loss: 0.3413
# Epoch 23: val_accuracy did not improve from 0.84211
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 360ms/step - accuracy: 0.8786 - loss: 0.3413 - val_accuracy: 0.8186 - val_loss: 0.5229
# Epoch 24/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.8724 - loss: 0.3535
# Epoch 24: val_accuracy improved from 0.84211 to 0.84591, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 363ms/step - accuracy: 0.8724 - loss: 0.3535 - val_accuracy: 0.8459 - val_loss: 0.4457
# Epoch 25/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.8966 - loss: 0.2953
# Epoch 25: val_accuracy did not improve from 0.84591
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 362ms/step - accuracy: 0.8965 - loss: 0.2955 - val_accuracy: 0.8440 - val_loss: 0.4528
# Epoch 26/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.8894 - loss: 0.3015
# Epoch 26: val_accuracy improved from 0.84591 to 0.85162, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 367ms/step - accuracy: 0.8894 - loss: 0.3015 - val_accuracy: 0.8516 - val_loss: 0.4478
# Epoch 27/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.8880 - loss: 0.2975
# Epoch 27: val_accuracy did not improve from 0.85162
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 359ms/step - accuracy: 0.8880 - loss: 0.2975 - val_accuracy: 0.8339 - val_loss: 0.5085
# Epoch 28/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9012 - loss: 0.2741
# Epoch 28: val_accuracy improved from 0.85162 to 0.85859, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 365ms/step - accuracy: 0.9012 - loss: 0.2741 - val_accuracy: 0.8586 - val_loss: 0.4519
# Epoch 29/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9101 - loss: 0.2653
# Epoch 29: val_accuracy did not improve from 0.85859
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 364ms/step - accuracy: 0.9100 - loss: 0.2654 - val_accuracy: 0.8396 - val_loss: 0.4919
# Epoch 30/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.9104 - loss: 0.2561
# Epoch 30: val_accuracy did not improve from 0.85859
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 359ms/step - accuracy: 0.9103 - loss: 0.2562 - val_accuracy: 0.8497 - val_loss: 0.4445
# Epoch 31/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9135 - loss: 0.2440
# Epoch 31: val_accuracy did not improve from 0.85859
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 363ms/step - accuracy: 0.9135 - loss: 0.2439 - val_accuracy: 0.8269 - val_loss: 0.5304
# Epoch 32/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.9238 - loss: 0.2186
# Epoch 32: val_accuracy improved from 0.85859 to 0.86303, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 364ms/step - accuracy: 0.9237 - loss: 0.2189 - val_accuracy: 0.8630 - val_loss: 0.4426
# Epoch 33/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.9189 - loss: 0.2376
# Epoch 33: val_accuracy did not improve from 0.86303
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 43s 359ms/step - accuracy: 0.9189 - loss: 0.2375 - val_accuracy: 0.8205 - val_loss: 0.6018
# Epoch 34/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.9133 - loss: 0.2392
# Epoch 34: val_accuracy did not improve from 0.86303
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 360ms/step - accuracy: 0.9134 - loss: 0.2390 - val_accuracy: 0.8326 - val_loss: 0.5421
# Epoch 35/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.9401 - loss: 0.1772
# Epoch 35: val_accuracy did not improve from 0.86303
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 362ms/step - accuracy: 0.9400 - loss: 0.1774 - val_accuracy: 0.8548 - val_loss: 0.4708
# Epoch 36/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.9332 - loss: 0.1884
# Epoch 36: val_accuracy did not improve from 0.86303
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 361ms/step - accuracy: 0.9332 - loss: 0.1885 - val_accuracy: 0.8618 - val_loss: 0.4575
# Epoch 37/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.9369 - loss: 0.1848
# Epoch 37: val_accuracy did not improve from 0.86303
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 365ms/step - accuracy: 0.9369 - loss: 0.1848 - val_accuracy: 0.8269 - val_loss: 0.5883
# Epoch 38/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.9354 - loss: 0.1748
# Epoch 38: val_accuracy did not improve from 0.86303
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 362ms/step - accuracy: 0.9354 - loss: 0.1749 - val_accuracy: 0.8630 - val_loss: 0.4682
# Epoch 39/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.9425 - loss: 0.1680
# Epoch 39: val_accuracy did not improve from 0.86303
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 361ms/step - accuracy: 0.9425 - loss: 0.1680 - val_accuracy: 0.8535 - val_loss: 0.5087
# Epoch 40/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.9526 - loss: 0.1378
# Epoch 40: val_accuracy did not improve from 0.86303
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 365ms/step - accuracy: 0.9526 - loss: 0.1379 - val_accuracy: 0.8561 - val_loss: 0.4937
# Epoch 41/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.9537 - loss: 0.1345
# Epoch 41: val_accuracy did not improve from 0.86303
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 359ms/step - accuracy: 0.9536 - loss: 0.1347 - val_accuracy: 0.8427 - val_loss: 0.5417
# Epoch 42/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.9484 - loss: 0.1416
# Epoch 42: val_accuracy did not improve from 0.86303
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 44s 359ms/step - accuracy: 0.9484 - loss: 0.1416 - val_accuracy: 0.8332 - val_loss: 0.5372

# %%
#Test the model with the test set

model.evaluate(testdata)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 141ms/step - accuracy: 0.8770 - loss: 0.4126
# [0.44264641404151917, 0.8630310893058777]

# %%
# Visualize the model

plt.plot(history.history['accuracy'], marker='o')
plt.plot(history.history['val_accuracy'], marker='o')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'], marker='o')
plt.plot(history.history['val_loss'], marker='o')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# Prediksi label kelas menggunakan model terhadap data uji
predictions = model.predict(testdata)
predicted_classes = np.argmax(predictions, axis=1)

# Ambil label sebenarnya dari data uji
true_classes = testdata.labels

# Dapatkan nama kelas
class_labels = list(testdata.class_indices.keys())

# Buat classification matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Print classification matrix
print("Classification Matrix:")
print(cm)

# Print classification report
print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))

# %% [markdown]
# Accuracy adalah rasio dari jumlah prediksi yang benar (true predictions) dibagi dengan jumlah total instance dalam dataset.

# %% [markdown]
# Precision mengukur seberapa akurat model dalam memprediksi kelas positif. Ini dihitung sebagai rasio dari true positive (TP) dibagi oleh jumlah true positive dan false positive (FP).

# %% [markdown]
#  Recall mengukur seberapa baik model dalam menemukan semua instance yang benar dari kelas yang diinginkan. Ini dihitung sebagai rasio dari true positive (TP) dibagi oleh jumlah true positive dan false negative (FN).

# %% [markdown]
# F1-score adalah rata-rata harmonik dari precision dan recall. Ini memberikan keseimbangan antara precision dan recall.

# %% [markdown]
# ### Mencoba dengan dataset lain

# %% [markdown]
# ### Dataset source: https://www.kaggle.com/datasets/annielu21/house-rooms

# %%
import os
import shutil

# Menggunakan direktori yang dapat ditulis
img_path2 = '/kaggle/input/house-rooms/room-dataset'
input_dir = 'images'
output_dir2 = 'new_output'

# Membuat folder output jika belum ada
os.makedirs(output_dir2, exist_ok=True)

# Membuat Folder Kategori
categories = ['bath', 'bed', 'din', 'kitchen', 'living']
for category in categories:
    category_dir = os.path.join(output_dir2, category)
    os.makedirs(category_dir, exist_ok=True)

# %%
folder_mapping = {
    'bathroom': 'bath',
    'bedroom': 'bed',
    'dining': 'din',
    'kitchen': 'kitchen',
    'living': 'living'
}

# %%
# Memindahkan file ke folder yang dipilih
for root, dirs, files in os.walk(img_path2):
    for file in files:
        category = os.path.basename(root)
        if category in folder_mapping:
            source_file = os.path.join(root, file)
            destination_dir = os.path.join(output_dir2, folder_mapping[category])
            shutil.copy(source_file, destination_dir)

# %%
for category in categories:
    category_dir = os.path.join(output_dir2, category)
    num_files = len(os.listdir(category_dir))
    print(f"Total {category} files: {num_files}")

# %%
# Define the ImageDataGenerator for the new dataset
new_datagen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=preprocess_input
)

# Create a generator for the new dataset
new_generator = new_datagen.flow_from_directory(
    directory=output_dir2,
    classes=['bath', 'bed', 'din', 'kitchen', 'living'],
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    batch_size=32,  # Specify the batch size
    shuffle=False  # Do not shuffle the data for testing
)

# %%
def create_model():

    np.random.seed(42)

    model = Sequential()
    model.add(Input(shape=(224,224,3)))
    model.add(base_model)
    model.add(Flatten())
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(len(categories), activation='softmax'))
    
    
    optimizer = SGD(learning_rate=0.005)
    
    model.compile(
      optimizer=optimizer,
      loss='categorical_crossentropy',
      metrics=['accuracy'])
    
    return model

model2 = create_model()

# %%
model2.summary()

# %%
model2.load_weights('/kaggle/working/output/bestmodel.keras')

# %%
model2.evaluate(new_generator)

# %% [markdown]
# ### Didapatkan akurasi 80% untuk dataset yang lain
