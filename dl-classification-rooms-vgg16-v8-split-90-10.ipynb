# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ### Dataset source: https://www.kaggle.com/datasets/mikhailma/house-rooms-streets-image-dataset

# %%
import glob as gb

import cv2
import matplotlib.pylab as plt

plt.style.use('ggplot')

# %%
import warnings

warnings.filterwarnings("ignore", message="All log messages before absl::InitializeLog() is called are written to STDERR")
warnings.filterwarnings("ignore", message="Fallback to op-by-op mode because memset node breaks graph update")

# %%
from sklearn.model_selection import train_test_split
import os
import shutil
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
# Out:
# 2024-06-14 07:49:41.805492: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-14 07:49:41.805594: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-14 07:49:41.953283: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def set_random_seed(random_seed):
    os.environ['PYTHONHASHSEED'] = str(random_seed)
    random.seed(random_seed)
    np.random.seed(random_seed)
    tf.random.set_seed(random_seed)
    
set_random_seed(42)

# %%
# Path gambar
img_path = "/kaggle/input/house-rooms-streets-image-dataset/kaggle_room_street_data/house_data"

input_dir = 'images'
output_dir = 'output'

# Membuat folder output jika belum ada
os.makedirs(output_dir, exist_ok=True)

# %%
# Membuat Folder Kategori
categories = ['bath', 'bed', 'din', 'kitchen', 'living']
for category in categories:
    category_dir = os.path.join(output_dir, category)
    os.makedirs(category_dir, exist_ok=True)

# %%
# Mencari Path Gambar
all_images = gb.glob(img_path + "/*.jpg")

# %%
# Memindahkan Gambar ke Folder Kategori yang Sesuai
for img_path in all_images:
    for category in categories:
        if category in img_path:
            shutil.copy(img_path, os.path.join(output_dir, category, os.path.basename(img_path)))
            break # Pindah ke gambar berikutnya setelah menemukan kategori

# %%
# Buat folder train dan test
train_dir = os.path.join(output_dir, "train")
test_dir = os.path.join(output_dir, "test")
if os.path.exists(train_dir):
    shutil.rmtree(train_dir)
if os.path.exists(test_dir):
    shutil.rmtree(test_dir)
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Split data menjadi 70%train 30%test
for category in categories:
    category_dir = os.path.join(output_dir, category)
    images = os.listdir(category_dir)
    train_images, test_images = train_test_split(images, test_size=0.1, random_state=42)
    
    # Pindahkan gambar-gambar ke dalam folder train dan test
    for img in train_images:
        target_dir = os.path.join(train_dir, category)
        os.makedirs(target_dir, exist_ok=True)
        shutil.move(os.path.join(category_dir, img), os.path.join(target_dir, img))

    for img in test_images:
        target_dir = os.path.join(test_dir, category)
        os.makedirs(target_dir, exist_ok=True)
        shutil.move(os.path.join(category_dir, img), os.path.join(target_dir, img))

# %%
# Cetak jumlah gambar dalam folder train
print("\nJumlah Gambar dalam Folder Train:")
for category in categories:
    train_category_dir = os.path.join(train_dir, category)
    num_train_images = len(os.listdir(train_category_dir))
    print(f"{category}: {num_train_images} gambar")

# Cetak jumlah gambar dalam folder test
print("\nJumlah Gambar dalam Folder Test:")
for category in categories:
    test_category_dir = os.path.join(test_dir, category)
    num_test_images = len(os.listdir(test_category_dir))
    print(f"{category}: {num_test_images} gambar")
# Out:
# Jumlah Gambar dalam Folder Train:
# bath: 544 gambar
# bed: 1123 gambar
# din: 1042 gambar
# kitchen: 868 gambar
# living: 1145 gambar
#
# Jumlah Gambar dalam Folder Test:
# bath: 61 gambar
# bed: 125 gambar
# din: 116 gambar
# kitchen: 97 gambar
# living: 128 gambar

# %%
def convert_to_grayscale(img):
    # Konversi gambar ke grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    return gray

# %%
def apply_clahe(gray_img):
    # Terapkan CLAHE pada gambar grayscale
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    clahe_img = clahe.apply(gray_img)
    
    # Gabungkan kembali ke tiga saluran RGB
    final_img = cv2.merge((clahe_img, clahe_img, clahe_img))
    return final_img

# %%
from keras.preprocessing import image

def preprocess_with_clahe(img):
    # Konversi gambar ke array dengan tipe data uint8
    img_array = image.img_to_array(img, dtype='uint8')
    # Konversi gambar ke grayscale
    gray_img = convert_to_grayscale(img_array)
    # Terapkan CLAHE pada gambar grayscale
    img_clahe = apply_clahe(gray_img)
    # Lakukan preprocess_input VGG16
    img_preprocessed = preprocess_input(img_clahe)
    return img_preprocessed

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.applications.vgg16 import preprocess_input

def visualize_random_images(folder, num_images=1, figsize=(8, 4)):
    categories = os.listdir(folder)
    for category in categories:
        category_dir = os.path.join(folder, category)
        images = os.listdir(category_dir)
        random_images = random.sample(images, num_images)
        print(f"\nContoh Gambar untuk Kategori {category}:")
        for img_file in random_images:
            img_path = os.path.join(category_dir, img_file)
            img = mpimg.imread(img_path)
            img_clahe = preprocess_with_clahe(img)
            
            fig, axes = plt.subplots(1, 2, figsize=figsize)
            axes[0].imshow(img)
            axes[0].set_title('Original Image')
            axes[0].axis("off")
            
            axes[1].imshow(img_clahe)
            axes[1].set_title('CLAHE Image')
            axes[1].axis("off")
            
            plt.show()

print('Train Folder')
visualize_random_images(train_dir, figsize=(8, 4))
print('\nTest Folder')
visualize_random_images(test_dir, figsize=(8, 4))
# Out:
# Train Folder
#
# Contoh Gambar untuk Kategori bed:
# Contoh Gambar untuk Kategori kitchen:
# Contoh Gambar untuk Kategori bath:
# Contoh Gambar untuk Kategori din:
# Contoh Gambar untuk Kategori living:
# Test Folder
#
# Contoh Gambar untuk Kategori bed:
# Contoh Gambar untuk Kategori kitchen:
# Contoh Gambar untuk Kategori bath:
# Contoh Gambar untuk Kategori din:
# Contoh Gambar untuk Kategori living:

# %%
# Membuat objek ImageDataGenerator untuk pelatihan dengan preprocessing CLAHE
train_datagen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=preprocess_with_clahe,
    samplewise_center=True,
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode='nearest'
)

traindata = train_datagen.flow_from_directory(
    directory="./output/train", 
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    shuffle=False)

# Membuat objek ImageDataGenerator untuk pengujian dengan preprocessing CLAHE
test_datagen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=preprocess_with_clahe,
    samplewise_center=True
)

testdata = test_datagen.flow_from_directory(
    directory="./output/test", 
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    shuffle=False)
# Out:
# Found 4722 images belonging to 5 classes.
# Found 527 images belonging to 5 classes.

# %%
# # Membuat objek ImageDataGenerator untuk pelatihan dengan preprocessing CLAHE
# train_datagen = ImageDataGenerator(
#     rescale=1./255,
#     preprocessing_function=preprocess_with_clahe,
#     samplewise_center=True,
#     rotation_range=10,
#     zoom_range=0.1,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     shear_range=0.1,
#     brightness_range=[0.8, 1.2],
#     horizontal_flip=True,
#     vertical_flip=False,
#     fill_mode='nearest'
# )

# traindata = train_datagen.flow_from_directory(
#     directory="./output/train", 
#     target_size=(224,224), 
#     color_mode="rgb", 
#     class_mode='categorical',
#     shuffle=False)

# # Membuat objek ImageDataGenerator untuk pengujian dengan preprocessing CLAHE
# test_datagen = ImageDataGenerator(
#     rescale=1./255,
#     preprocessing_function=preprocess_with_clahe,
#     samplewise_center=True
# )

# testdata = test_datagen.flow_from_directory(
#     directory="./output/test", 
#     target_size=(224,224), 
#     color_mode="rgb", 
#     class_mode='categorical',
#     shuffle=False)

# %%
testdata.class_indices
# Out:
# {'bath': 0, 'bed': 1, 'din': 2, 'kitchen': 3, 'living': 4}

# %% [markdown]
# ### MODELING

# %%
# VGG16 model (VGG16 is a famous convolution neural net (CNN) architecture 
# invented by Karen Simonyan and Andrew Zisserman in 2014.)

from keras.applications.vgg16 import VGG16

base_model = VGG16(input_shape=(224,224,3), include_top=False, weights='imagenet')

base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# freeze semua layer kecuali 2,3,4 layer dari akhir
for layer in base_model.layers:
    layer.trainable = False
base_model.layers[-2].trainable = True
base_model.layers[-3].trainable = True
base_model.layers[-4].trainable = True

# %%
# base_model.trainable = False

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from keras.regularizers import l2
import tensorflow as tf

# model = Sequential()
# model.add(Input(shape=(224, 224, 3)))
# model.add(base_model)
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(GlobalAveragePooling2D())

# # Adding additional Dense layers with Batch Normalization
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(Dense(256, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(Dense(len(categories), activation='softmax'))

model = Sequential()
model.add(Input(shape=(224, 224, 3)))
model.add(base_model)
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dropout(0.1))
model.add(Dense(512, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.1))
model.add(Dense(256, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.1))
model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.1))
model.add(Dense(len(categories), activation='softmax', kernel_regularizer=l2(0.01)))



# model = Sequential()
# model.add(Input(shape=(224, 224, 3)))
# model.add(base_model)
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Flatten())
# model.add(Dropout(0.2))
# model.add(Dense(256, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(len(categories), activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 7, 7, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,239,365 (65.76 MB)
#  Trainable params: 9,604,101 (36.64 MB)
#  Non-trainable params: 7,635,264 (29.13 MB)

# %%
from tensorflow.keras.optimizers import SGD  # Import SGD optimizer
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.callbacks import ReduceLROnPlateau

#maxpooling 2x2 86.30310893058777%
#maxpooling 3x3 85.60557961463928%
#avgpooling 2x2 85.54216623306274%
#avgpooling 3x3 82.81547427177429%

#maxpool 2x2 + grayscale clahe  87.38110065460205%

device_name = tf.test.gpu_device_name()

np.random.seed(42)

modelpath = './output/bestmodel.keras'

### train the model
with tf.device(device_name):
    
    optimizer = SGD(learning_rate=0.005)
    
    model.compile(
      optimizer=optimizer,
      loss='categorical_crossentropy',
      metrics=['accuracy'])

    # Early stopping for val_accuracy
    early_stopping_acc = EarlyStopping(monitor='val_accuracy', patience=10, 
                                       restore_best_weights=True, mode='max')

    # Early stopping for val_loss
    early_stopping_loss = EarlyStopping(monitor='val_loss', patience=5, 
                                        restore_best_weights=True, mode='min')

    
    # Reduce learning rate when a metric has stopped improving
    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, 
                                  patience=8, min_lr=0.000005, verbose=1)

    
    # Callback ModelCheckpoint untuk menyimpan bobot terbaik
    checkpoint = ModelCheckpoint(
        modelpath,
        monitor='val_accuracy',
        save_best_only=True,  # Hanya menyimpan bobot terbaik
        mode='max',  # Mode untuk membandingkan nilai metrik (misalnya 'max' untuk akurasi)
        verbose=1  # Menampilkan pesan saat menyimpan
    )

    # Train the model
    history = model.fit(x=traindata, validation_data=testdata, epochs=200, 
                        batch_size=32, callbacks=[early_stopping_acc, early_stopping_loss,
                                                  checkpoint,reduce_lr])
# Out:
# Epoch 1/200
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1718351473.943373     107 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1718351473.965134     107 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#   2/148 ━━━━━━━━━━━━━━━━━━━━ 1:01:11 25s/step - accuracy: 0.7694 - loss: 15.3330
# W0000 00:00:1718351499.142929     107 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - accuracy: 0.2409 - loss: 15.9986
# W0000 00:00:1718351554.593799     107 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1718351573.149429     105 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.38140, saving model to ./output/bestmodel.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 140s 677ms/step - accuracy: 0.2409 - loss: 15.9975 - val_accuracy: 0.3814 - val_loss: 15.5142 - learning_rate: 0.0050
# Epoch 2/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.3713 - loss: 15.3484
# Epoch 2: val_accuracy improved from 0.38140 to 0.58254, saving model to ./output/bestmodel.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 61s 394ms/step - accuracy: 0.3715 - loss: 15.3475 - val_accuracy: 0.5825 - val_loss: 14.7844 - learning_rate: 0.0050
# Epoch 3/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.5363 - loss: 14.6811
# Epoch 3: val_accuracy improved from 0.58254 to 0.62429, saving model to ./output/bestmodel.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 389ms/step - accuracy: 0.5363 - loss: 14.6804 - val_accuracy: 0.6243 - val_loss: 14.1938 - learning_rate: 0.0050
# Epoch 4/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.5748 - loss: 14.1999
# Epoch 4: val_accuracy improved from 0.62429 to 0.71537, saving model to ./output/bestmodel.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 61s 393ms/step - accuracy: 0.5749 - loss: 14.1990 - val_accuracy: 0.7154 - val_loss: 13.6101 - learning_rate: 0.0050
# Epoch 5/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6465 - loss: 13.6831
# Epoch 5: val_accuracy did not improve from 0.71537
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 389ms/step - accuracy: 0.6464 - loss: 13.6824 - val_accuracy: 0.7078 - val_loss: 13.1803 - learning_rate: 0.0050
# Epoch 6/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.6611 - loss: 13.2707
# Epoch 6: val_accuracy improved from 0.71537 to 0.77230, saving model to ./output/bestmodel.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 389ms/step - accuracy: 0.6612 - loss: 13.2697 - val_accuracy: 0.7723 - val_loss: 12.7541 - learning_rate: 0.0050
# Epoch 7/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.7126 - loss: 12.8086
# Epoch 7: val_accuracy did not improve from 0.77230
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 384ms/step - accuracy: 0.7126 - loss: 12.8080 - val_accuracy: 0.7211 - val_loss: 12.4881 - learning_rate: 0.0050
# Epoch 8/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.7190 - loss: 12.4062
# Epoch 8: val_accuracy improved from 0.77230 to 0.79317, saving model to ./output/bestmodel.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 387ms/step - accuracy: 0.7190 - loss: 12.4056 - val_accuracy: 0.7932 - val_loss: 11.9765 - learning_rate: 0.0050
# Epoch 9/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.7354 - loss: 12.0472
# Epoch 9: val_accuracy did not improve from 0.79317
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 390ms/step - accuracy: 0.7355 - loss: 12.0465 - val_accuracy: 0.7875 - val_loss: 11.6924 - learning_rate: 0.0050
# Epoch 10/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.7652 - loss: 11.6419
# Epoch 10: val_accuracy did not improve from 0.79317
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 388ms/step - accuracy: 0.7652 - loss: 11.6414 - val_accuracy: 0.7609 - val_loss: 11.3916 - learning_rate: 0.0050
# Epoch 11/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.7700 - loss: 11.3176
# Epoch 11: val_accuracy improved from 0.79317 to 0.83302, saving model to ./output/bestmodel.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 390ms/step - accuracy: 0.7700 - loss: 11.3171 - val_accuracy: 0.8330 - val_loss: 10.9265 - learning_rate: 0.0050
# Epoch 12/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.8044 - loss: 10.9370
# Epoch 12: val_accuracy did not improve from 0.83302
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 391ms/step - accuracy: 0.8043 - loss: 10.9367 - val_accuracy: 0.8121 - val_loss: 10.6609 - learning_rate: 0.0050
# Epoch 13/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.7956 - loss: 10.6697
# Epoch 13: val_accuracy did not improve from 0.83302
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 387ms/step - accuracy: 0.7956 - loss: 10.6691 - val_accuracy: 0.7951 - val_loss: 10.3794 - learning_rate: 0.0050
# Epoch 14/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.8136 - loss: 10.3297
# Epoch 14: val_accuracy did not improve from 0.83302
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 384ms/step - accuracy: 0.8136 - loss: 10.3293 - val_accuracy: 0.8159 - val_loss: 10.0598 - learning_rate: 0.0050
# Epoch 15/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.8105 - loss: 10.0333
# Epoch 15: val_accuracy did not improve from 0.83302
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 385ms/step - accuracy: 0.8106 - loss: 10.0328 - val_accuracy: 0.8311 - val_loss: 9.8065 - learning_rate: 0.0050
# Epoch 16/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.8113 - loss: 9.7559
# Epoch 16: val_accuracy improved from 0.83302 to 0.83491, saving model to ./output/bestmodel.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 387ms/step - accuracy: 0.8113 - loss: 9.7554 - val_accuracy: 0.8349 - val_loss: 9.4508 - learning_rate: 0.0050
# Epoch 17/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.8376 - loss: 9.4201
# Epoch 17: val_accuracy improved from 0.83491 to 0.84630, saving model to ./output/bestmodel.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 386ms/step - accuracy: 0.8375 - loss: 9.4199 - val_accuracy: 0.8463 - val_loss: 9.2359 - learning_rate: 0.0050
# Epoch 18/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.8345 - loss: 9.1831
# Epoch 18: val_accuracy did not improve from 0.84630
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 390ms/step - accuracy: 0.8345 - loss: 9.1827 - val_accuracy: 0.8425 - val_loss: 8.9552 - learning_rate: 0.0050
# Epoch 19/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.8409 - loss: 8.9046
# Epoch 19: val_accuracy did not improve from 0.84630
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 385ms/step - accuracy: 0.8410 - loss: 8.9041 - val_accuracy: 0.8463 - val_loss: 8.6770 - learning_rate: 0.0050
# Epoch 20/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.8438 - loss: 8.6637
# Epoch 20: val_accuracy did not improve from 0.84630
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 386ms/step - accuracy: 0.8438 - loss: 8.6632 - val_accuracy: 0.8065 - val_loss: 8.5078 - learning_rate: 0.0050
# Epoch 21/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.8322 - loss: 8.4285
# Epoch 21: val_accuracy did not improve from 0.84630
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 385ms/step - accuracy: 0.8323 - loss: 8.4280 - val_accuracy: 0.8349 - val_loss: 8.2976 - learning_rate: 0.0050
# Epoch 22/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.8577 - loss: 8.1316
# Epoch 22: val_accuracy improved from 0.84630 to 0.85009, saving model to ./output/bestmodel.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 387ms/step - accuracy: 0.8577 - loss: 8.1313 - val_accuracy: 0.8501 - val_loss: 7.9756 - learning_rate: 0.0050
# Epoch 23/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.8622 - loss: 7.9255
# Epoch 23: val_accuracy improved from 0.85009 to 0.85199, saving model to ./output/bestmodel.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 59s 382ms/step - accuracy: 0.8622 - loss: 7.9251 - val_accuracy: 0.8520 - val_loss: 7.7656 - learning_rate: 0.0050
# Epoch 24/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.8726 - loss: 7.6809
# Epoch 24: val_accuracy did not improve from 0.85199
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 384ms/step - accuracy: 0.8725 - loss: 7.6806 - val_accuracy: 0.8140 - val_loss: 7.7062 - learning_rate: 0.0050
# Epoch 25/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.8733 - loss: 7.4679
# Epoch 25: val_accuracy improved from 0.85199 to 0.85389, saving model to ./output/bestmodel.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 388ms/step - accuracy: 0.8733 - loss: 7.4676 - val_accuracy: 0.8539 - val_loss: 7.3406 - learning_rate: 0.0050
# Epoch 26/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.8698 - loss: 7.2571
# Epoch 26: val_accuracy did not improve from 0.85389
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 59s 382ms/step - accuracy: 0.8698 - loss: 7.2567 - val_accuracy: 0.8539 - val_loss: 7.1862 - learning_rate: 0.0050
# Epoch 27/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.8828 - loss: 7.0213
# Epoch 27: val_accuracy improved from 0.85389 to 0.86528, saving model to ./output/bestmodel.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 387ms/step - accuracy: 0.8828 - loss: 7.0211 - val_accuracy: 0.8653 - val_loss: 6.9295 - learning_rate: 0.0050
# Epoch 28/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.8683 - loss: 6.8763
# Epoch 28: val_accuracy did not improve from 0.86528
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 59s 382ms/step - accuracy: 0.8684 - loss: 6.8759 - val_accuracy: 0.8558 - val_loss: 6.7627 - learning_rate: 0.0050
# Epoch 29/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.8715 - loss: 6.6661
# Epoch 29: val_accuracy improved from 0.86528 to 0.86907, saving model to ./output/bestmodel.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 59s 383ms/step - accuracy: 0.8715 - loss: 6.6658 - val_accuracy: 0.8691 - val_loss: 6.5577 - learning_rate: 0.0050
# Epoch 30/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.8835 - loss: 6.4719
# Epoch 30: val_accuracy improved from 0.86907 to 0.87476, saving model to ./output/bestmodel.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 386ms/step - accuracy: 0.8835 - loss: 6.4716 - val_accuracy: 0.8748 - val_loss: 6.3692 - learning_rate: 0.0050
# Epoch 31/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.8920 - loss: 6.3000
# Epoch 31: val_accuracy did not improve from 0.87476
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 59s 383ms/step - accuracy: 0.8920 - loss: 6.2998 - val_accuracy: 0.8672 - val_loss: 6.2177 - learning_rate: 0.0050
# Epoch 32/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.8958 - loss: 6.1112
# Epoch 32: val_accuracy did not improve from 0.87476
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 385ms/step - accuracy: 0.8958 - loss: 6.1109 - val_accuracy: 0.8653 - val_loss: 6.0312 - learning_rate: 0.0050
# Epoch 33/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.9081 - loss: 5.9067
# Epoch 33: val_accuracy did not improve from 0.87476
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 385ms/step - accuracy: 0.9080 - loss: 5.9066 - val_accuracy: 0.8710 - val_loss: 5.8960 - learning_rate: 0.0050
# Epoch 34/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.9083 - loss: 5.7302
# Epoch 34: val_accuracy did not improve from 0.87476
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 386ms/step - accuracy: 0.9083 - loss: 5.7300 - val_accuracy: 0.8501 - val_loss: 5.8255 - learning_rate: 0.0050
# Epoch 35/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.8921 - loss: 5.6269
# Epoch 35: val_accuracy did not improve from 0.87476
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 385ms/step - accuracy: 0.8921 - loss: 5.6265 - val_accuracy: 0.8729 - val_loss: 5.5472 - learning_rate: 0.0050
# Epoch 36/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9065 - loss: 5.4489
# Epoch 36: val_accuracy did not improve from 0.87476
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 383ms/step - accuracy: 0.9064 - loss: 5.4486 - val_accuracy: 0.8539 - val_loss: 5.4565 - learning_rate: 0.0050
# Epoch 37/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9066 - loss: 5.2854
# Epoch 37: val_accuracy did not improve from 0.87476
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 59s 383ms/step - accuracy: 0.9066 - loss: 5.2851 - val_accuracy: 0.8539 - val_loss: 5.3781 - learning_rate: 0.0050
# Epoch 38/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.9125 - loss: 5.1314
# Epoch 38: val_accuracy improved from 0.87476 to 0.88235, saving model to ./output/bestmodel.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 384ms/step - accuracy: 0.9125 - loss: 5.1312 - val_accuracy: 0.8824 - val_loss: 5.1555 - learning_rate: 0.0050
# Epoch 39/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.9260 - loss: 4.9684
# Epoch 39: val_accuracy did not improve from 0.88235
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 387ms/step - accuracy: 0.9259 - loss: 4.9684 - val_accuracy: 0.8767 - val_loss: 4.9815 - learning_rate: 0.0050
# Epoch 40/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9121 - loss: 4.8595
# Epoch 40: val_accuracy did not improve from 0.88235
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 59s 382ms/step - accuracy: 0.9122 - loss: 4.8592 - val_accuracy: 0.8615 - val_loss: 4.9342 - learning_rate: 0.0050
# Epoch 41/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.9173 - loss: 4.7131
# Epoch 41: val_accuracy did not improve from 0.88235
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 387ms/step - accuracy: 0.9173 - loss: 4.7130 - val_accuracy: 0.8691 - val_loss: 4.7785 - learning_rate: 0.0050
# Epoch 42/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.9208 - loss: 4.5724
# Epoch 42: val_accuracy did not improve from 0.88235
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 385ms/step - accuracy: 0.9208 - loss: 4.5723 - val_accuracy: 0.8634 - val_loss: 4.6308 - learning_rate: 0.0050
# Epoch 43/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.9224 - loss: 4.4406
# Epoch 43: val_accuracy did not improve from 0.88235
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 383ms/step - accuracy: 0.9224 - loss: 4.4405 - val_accuracy: 0.8710 - val_loss: 4.4856 - learning_rate: 0.0050
# Epoch 44/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.9278 - loss: 4.3167
# Epoch 44: val_accuracy did not improve from 0.88235
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 384ms/step - accuracy: 0.9278 - loss: 4.3165 - val_accuracy: 0.8634 - val_loss: 4.3993 - learning_rate: 0.0050
# Epoch 45/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9308 - loss: 4.2028
# Epoch 45: val_accuracy did not improve from 0.88235
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 59s 383ms/step - accuracy: 0.9308 - loss: 4.2026 - val_accuracy: 0.8634 - val_loss: 4.2844 - learning_rate: 0.0050
# Epoch 46/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.9376 - loss: 4.0686
# Epoch 46: val_accuracy did not improve from 0.88235
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0004999999888241291.
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 59s 383ms/step - accuracy: 0.9376 - loss: 4.0685 - val_accuracy: 0.8710 - val_loss: 4.1882 - learning_rate: 0.0050
# Epoch 47/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9366 - loss: 3.9761
# Epoch 47: val_accuracy improved from 0.88235 to 0.89374, saving model to ./output/bestmodel.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 384ms/step - accuracy: 0.9366 - loss: 3.9760 - val_accuracy: 0.8937 - val_loss: 4.1177 - learning_rate: 5.0000e-04
# Epoch 48/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.9515 - loss: 3.9310
# Epoch 48: val_accuracy improved from 0.89374 to 0.89753, saving model to ./output/bestmodel.keras
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 389ms/step - accuracy: 0.9515 - loss: 3.9309 - val_accuracy: 0.8975 - val_loss: 4.1100 - learning_rate: 5.0000e-04
# Epoch 49/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.9577 - loss: 3.9010
# Epoch 49: val_accuracy did not improve from 0.89753
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 385ms/step - accuracy: 0.9577 - loss: 3.9011 - val_accuracy: 0.8937 - val_loss: 4.1070 - learning_rate: 5.0000e-04
# Epoch 50/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.9520 - loss: 3.9181
# Epoch 50: val_accuracy did not improve from 0.89753
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 61s 392ms/step - accuracy: 0.9520 - loss: 3.9180 - val_accuracy: 0.8975 - val_loss: 4.0897 - learning_rate: 5.0000e-04
# Epoch 51/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.9507 - loss: 3.8957
# Epoch 51: val_accuracy did not improve from 0.89753
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 387ms/step - accuracy: 0.9507 - loss: 3.8957 - val_accuracy: 0.8956 - val_loss: 4.0808 - learning_rate: 5.0000e-04
# Epoch 52/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.9546 - loss: 3.8925
# Epoch 52: val_accuracy did not improve from 0.89753
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 386ms/step - accuracy: 0.9546 - loss: 3.8924 - val_accuracy: 0.8956 - val_loss: 4.0692 - learning_rate: 5.0000e-04
# Epoch 53/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.9578 - loss: 3.8407
# Epoch 55: val_accuracy did not improve from 0.89753
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 386ms/step - accuracy: 0.9578 - loss: 3.8407 - val_accuracy: 0.8937 - val_loss: 4.0344 - learning_rate: 5.0000e-04
# Epoch 56/200
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9630 - loss: 3.8244
# Epoch 56: val_accuracy did not improve from 0.89753
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 4.9999996554106475e-05.
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 384ms/step - accuracy: 0.9630 - loss: 3.8245 - val_accuracy: 0.8937 - val_loss: 4.0265 - learning_rate: 5.0000e-04
# Epoch 57/200
#  92/148 ━━━━━━━━━━━━━━━━━━━━ 21s 381ms/step - accuracy: 0.9530 - loss: 3.8211

# %%
#Test the model with the test set

model.evaluate(testdata)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.9171 - loss: 3.9000
# [4.023344993591309, 0.8956356644630432]

# %%
# Visualize the model

plt.plot(history.history['accuracy'], marker='o')
plt.plot(history.history['val_accuracy'], marker='o')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'], marker='o')
plt.plot(history.history['val_loss'], marker='o')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# Prediksi label kelas menggunakan model terhadap data uji
predictions = model.predict(testdata)
predicted_classes = np.argmax(predictions, axis=1)

# Ambil label sebenarnya dari data uji
true_classes = testdata.labels

# Dapatkan nama kelas
class_labels = list(testdata.class_indices.keys())

# Buat classification matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Print classification matrix
print("Classification Matrix:")
print(cm)

# Print classification report
print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))
# Out:
#  2/17 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step
# W0000 00:00:1718355203.067939     105 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step
# Classification Matrix:
# [[ 57   0   1   3   0]
#  [  1 119   0   1   4]
#  [  1   2 101   7   5]
#  [  0   0  10  86   1]
#  [  1   9   6   3 109]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         bath       0.95      0.93      0.94        61
#          bed       0.92      0.95      0.93       125
#          din       0.86      0.87      0.86       116
#      kitchen       0.86      0.89      0.87        97
#       living       0.92      0.85      0.88       128
#
#     accuracy                           0.90       527
#    macro avg       0.90      0.90      0.90       527
# weighted avg       0.90      0.90      0.90       527
# W0000 00:00:1718355205.811093     108 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update

# %% [markdown]
# Accuracy adalah rasio dari jumlah prediksi yang benar (true predictions) dibagi dengan jumlah total instance dalam dataset.

# %% [markdown]
# Precision mengukur seberapa akurat model dalam memprediksi kelas positif. Ini dihitung sebagai rasio dari true positive (TP) dibagi oleh jumlah true positive dan false positive (FP).

# %% [markdown]
#  Recall mengukur seberapa baik model dalam menemukan semua instance yang benar dari kelas yang diinginkan. Ini dihitung sebagai rasio dari true positive (TP) dibagi oleh jumlah true positive dan false negative (FN).

# %% [markdown]
# F1-score adalah rata-rata harmonik dari precision dan recall. Ini memberikan keseimbangan antara precision dan recall.
