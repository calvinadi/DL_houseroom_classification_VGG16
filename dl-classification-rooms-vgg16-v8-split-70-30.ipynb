# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ### Dataset source: https://www.kaggle.com/datasets/mikhailma/house-rooms-streets-image-dataset

# %%
import glob as gb

import cv2
import matplotlib.pylab as plt

plt.style.use('ggplot')

# %%
import warnings

warnings.filterwarnings("ignore", message="All log messages before absl::InitializeLog() is called are written to STDERR")
warnings.filterwarnings("ignore", message="Fallback to op-by-op mode because memset node breaks graph update")

# %%
from sklearn.model_selection import train_test_split
import os
import shutil
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
# Out:
# 2024-06-13 11:45:19.732516: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-13 11:45:19.732569: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-13 11:45:19.734253: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    tf.random.set_seed(random_seed)
    
set_random_seed(42)

# %%
# Path gambar
img_path = "/kaggle/input/house-rooms-streets-image-dataset/kaggle_room_street_data/house_data"

input_dir = 'images'
output_dir = 'output'

# Membuat folder output jika belum ada
os.makedirs(output_dir, exist_ok=True)

# %%
# Membuat Folder Kategori
categories = ['bath', 'bed', 'din', 'kitchen', 'living']
for category in categories:
    category_dir = os.path.join(output_dir, category)
    os.makedirs(category_dir, exist_ok=True)

# %%
# Mencari Path Gambar
all_images = gb.glob(img_path + "/*.jpg")

# %%
# Memindahkan Gambar ke Folder Kategori yang Sesuai
for img_path in all_images:
    for category in categories:
        if category in img_path:
            shutil.copy(img_path, os.path.join(output_dir, category, os.path.basename(img_path)))
            break # Pindah ke gambar berikutnya setelah menemukan kategori

# %%
# Buat folder train dan test
train_dir = os.path.join(output_dir, "train")
test_dir = os.path.join(output_dir, "test")
if os.path.exists(train_dir):
    shutil.rmtree(train_dir)
if os.path.exists(test_dir):
    shutil.rmtree(test_dir)
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Split data menjadi 70%train 30%test
for category in categories:
    category_dir = os.path.join(output_dir, category)
    images = os.listdir(category_dir)
    train_images, test_images = train_test_split(images, test_size=0.3, random_state=42)
    
    # Pindahkan gambar-gambar ke dalam folder train dan test
    for img in train_images:
        target_dir = os.path.join(train_dir, category)
        os.makedirs(target_dir, exist_ok=True)
        shutil.move(os.path.join(category_dir, img), os.path.join(target_dir, img))

    for img in test_images:
        target_dir = os.path.join(test_dir, category)
        os.makedirs(target_dir, exist_ok=True)
        shutil.move(os.path.join(category_dir, img), os.path.join(target_dir, img))

# %%
# Cetak jumlah gambar dalam folder train
print("\nJumlah Gambar dalam Folder Train:")
for category in categories:
    train_category_dir = os.path.join(train_dir, category)
    num_train_images = len(os.listdir(train_category_dir))
    print(f"{category}: {num_train_images} gambar")

# Cetak jumlah gambar dalam folder test
print("\nJumlah Gambar dalam Folder Test:")
for category in categories:
    test_category_dir = os.path.join(test_dir, category)
    num_test_images = len(os.listdir(test_category_dir))
    print(f"{category}: {num_test_images} gambar")
# Out:
# Jumlah Gambar dalam Folder Train:
# bath: 423 gambar
# bed: 873 gambar
# din: 810 gambar
# kitchen: 675 gambar
# living: 891 gambar
#
# Jumlah Gambar dalam Folder Test:
# bath: 182 gambar
# bed: 375 gambar
# din: 348 gambar
# kitchen: 290 gambar
# living: 382 gambar

# %%
def convert_to_grayscale(img):
    # Konversi gambar ke grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    return gray

# %%
def apply_clahe(gray_img):
    # Terapkan CLAHE pada gambar grayscale
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    clahe_img = clahe.apply(gray_img)
    
    # Gabungkan kembali ke tiga saluran RGB
    final_img = cv2.merge((clahe_img, clahe_img, clahe_img))
    return final_img

# %%
from keras.preprocessing import image

def preprocess_with_clahe(img):
    # Konversi gambar ke array dengan tipe data uint8
    img_array = image.img_to_array(img, dtype='uint8')
    # Konversi gambar ke grayscale
    gray_img = convert_to_grayscale(img_array)
    # Terapkan CLAHE pada gambar grayscale
    img_clahe = apply_clahe(gray_img)
    # Lakukan preprocess_input VGG16
    img_preprocessed = preprocess_input(img_clahe)
    return img_preprocessed

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.applications.vgg16 import preprocess_input

def visualize_random_images(folder, num_images=1, figsize=(8, 4)):
    categories = os.listdir(folder)
    for category in categories:
        category_dir = os.path.join(folder, category)
        images = os.listdir(category_dir)
        random_images = random.sample(images, num_images)
        print(f"\nContoh Gambar untuk Kategori {category}:")
        for img_file in random_images:
            img_path = os.path.join(category_dir, img_file)
            img = mpimg.imread(img_path)
            img_clahe = preprocess_with_clahe(img)
            
            fig, axes = plt.subplots(1, 2, figsize=figsize)
            axes[0].imshow(img)
            axes[0].set_title('Original Image')
            axes[0].axis("off")
            
            axes[1].imshow(img_clahe)
            axes[1].set_title('CLAHE Image')
            axes[1].axis("off")
            
            plt.show()

print('Train Folder')
visualize_random_images(train_dir, figsize=(8, 4))
print('\nTest Folder')
visualize_random_images(test_dir, figsize=(8, 4))
# Out:
# Train Folder
#
# Contoh Gambar untuk Kategori bed:
# Contoh Gambar untuk Kategori bath:
# Contoh Gambar untuk Kategori kitchen:
# Contoh Gambar untuk Kategori din:
# Contoh Gambar untuk Kategori living:
# Test Folder
#
# Contoh Gambar untuk Kategori bed:
# Contoh Gambar untuk Kategori bath:
# Contoh Gambar untuk Kategori kitchen:
# Contoh Gambar untuk Kategori din:
# Contoh Gambar untuk Kategori living:

# %%
# Membuat objek ImageDataGenerator untuk pelatihan dengan preprocessing CLAHE
train_datagen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=preprocess_with_clahe,
    samplewise_center=True,
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode='nearest'
)

traindata = train_datagen.flow_from_directory(
    directory="./output/train", 
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    shuffle=False)

# Membuat objek ImageDataGenerator untuk pengujian dengan preprocessing CLAHE
test_datagen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=preprocess_with_clahe,
    samplewise_center=True
)

testdata = test_datagen.flow_from_directory(
    directory="./output/test", 
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    shuffle=False)
# Out:
# Found 3672 images belonging to 5 classes.
# Found 1577 images belonging to 5 classes.

# %%
# # Membuat objek ImageDataGenerator untuk pelatihan dengan preprocessing CLAHE
# train_datagen = ImageDataGenerator(
#     rescale=1./255,
#     preprocessing_function=preprocess_with_clahe,
#     samplewise_center=True,
#     rotation_range=10,
#     zoom_range=0.1,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     shear_range=0.1,
#     brightness_range=[0.8, 1.2],
#     horizontal_flip=True,
#     vertical_flip=False,
#     fill_mode='nearest'
# )

# traindata = train_datagen.flow_from_directory(
#     directory="./output/train", 
#     target_size=(224,224), 
#     color_mode="rgb", 
#     class_mode='categorical',
#     shuffle=False)

# # Membuat objek ImageDataGenerator untuk pengujian dengan preprocessing CLAHE
# test_datagen = ImageDataGenerator(
#     rescale=1./255,
#     preprocessing_function=preprocess_with_clahe,
#     samplewise_center=True
# )

# testdata = test_datagen.flow_from_directory(
#     directory="./output/test", 
#     target_size=(224,224), 
#     color_mode="rgb", 
#     class_mode='categorical',
#     shuffle=False)

# %%
testdata.class_indices
# Out:
# {'bath': 0, 'bed': 1, 'din': 2, 'kitchen': 3, 'living': 4}

# %% [markdown]
# ### MODELING

# %%
# VGG16 model (VGG16 is a famous convolution neural net (CNN) architecture 
# invented by Karen Simonyan and Andrew Zisserman in 2014.)

from keras.applications.vgg16 import VGG16

base_model = VGG16(input_shape=(224,224,3), include_top=False, weights='imagenet')

base_model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# freeze semua layer kecuali 2,3,4 layer dari akhir
for layer in base_model.layers:
    layer.trainable = False
base_model.layers[-2].trainable = True
base_model.layers[-3].trainable = True
base_model.layers[-4].trainable = True

# %%
# base_model.trainable = False

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from keras.regularizers import l2
import tensorflow as tf

# model = Sequential()
# model.add(Input(shape=(224, 224, 3)))
# model.add(base_model)
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(GlobalAveragePooling2D())

# # Adding additional Dense layers with Batch Normalization
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(Dense(256, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(Dense(len(categories), activation='softmax'))

model = Sequential()
model.add(Input(shape=(224, 224, 3)))
model.add(base_model)
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dropout(0.1))
model.add(Dense(512, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.1))
model.add(Dense(256, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.1))
model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.1))
model.add(Dense(len(categories), activation='softmax', kernel_regularizer=l2(0.01)))



# model = Sequential()
# model.add(Input(shape=(224, 224, 3)))
# model.add(base_model)
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Flatten())
# model.add(Dropout(0.2))
# model.add(Dense(256, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(len(categories), activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 7, 7, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,239,365 (65.76 MB)
#  Trainable params: 9,604,101 (36.64 MB)
#  Non-trainable params: 7,635,264 (29.13 MB)

# %%
from tensorflow.keras.optimizers import SGD  # Import SGD optimizer
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.callbacks import ReduceLROnPlateau

#maxpooling 2x2 86.30310893058777%
#maxpooling 3x3 85.60557961463928%
#avgpooling 2x2 85.54216623306274%
#avgpooling 3x3 82.81547427177429%

#maxpool 2x2 + grayscale clahe  87.38110065460205%

device_name = tf.test.gpu_device_name()

np.random.seed(42)

modelpath = './output/bestmodel.keras'

### train the model
with tf.device(device_name):
    
    optimizer = SGD(learning_rate=0.005)
    
    model.compile(
      optimizer=optimizer,
      loss='categorical_crossentropy',
      metrics=['accuracy'])

    # Early stopping for val_accuracy
    early_stopping_acc = EarlyStopping(monitor='val_accuracy', patience=10, 
                                       restore_best_weights=True, mode='max')

    # Early stopping for val_loss
    early_stopping_loss = EarlyStopping(monitor='val_loss', patience=5, 
                                        restore_best_weights=True, mode='min')

    
    # Reduce learning rate when a metric has stopped improving
    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, 
                                  patience=8, min_lr=0.000005, verbose=1)

    
    # Callback ModelCheckpoint untuk menyimpan bobot terbaik
    checkpoint = ModelCheckpoint(
        modelpath,
        monitor='val_accuracy',
        save_best_only=True,  # Hanya menyimpan bobot terbaik
        mode='max',  # Mode untuk membandingkan nilai metrik (misalnya 'max' untuk akurasi)
        verbose=1  # Menampilkan pesan saat menyimpan
    )

    # Train the model
    history = model.fit(x=traindata, validation_data=testdata, epochs=200, 
                        batch_size=32, callbacks=[early_stopping_acc, early_stopping_loss,
                                                  checkpoint,reduce_lr])
# Out:
# Epoch 1/200
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   1/115 ━━━━━━━━━━━━━━━━━━━━ 1:24:18 44s/step - accuracy: 0.0312 - loss: 16.6454
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1718279185.282571    1049 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1718279185.302328    1049 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#  25/115 ━━━━━━━━━━━━━━━━━━━━ 2:31 2s/step - accuracy: 0.2113 - loss: 16.3194
# W0000 00:00:1718279225.796013    1050 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 639ms/step - accuracy: 0.2368 - loss: 16.0905
# W0000 00:00:1718279259.836690    1050 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1718279277.959754    1050 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.42295, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 137s 816ms/step - accuracy: 0.2369 - loss: 16.0889 - val_accuracy: 0.4230 - val_loss: 15.5661 - learning_rate: 0.0050
# Epoch 2/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.2755 - loss: 15.5468
# Epoch 2: val_accuracy improved from 0.42295 to 0.42866, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 60s 444ms/step - accuracy: 0.2760 - loss: 15.5457 - val_accuracy: 0.4287 - val_loss: 15.0616 - learning_rate: 0.0050
# Epoch 3/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.4380 - loss: 15.0219
# Epoch 3: val_accuracy improved from 0.42866 to 0.62080, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 53s 434ms/step - accuracy: 0.4381 - loss: 15.0211 - val_accuracy: 0.6208 - val_loss: 14.5053 - learning_rate: 0.0050
# Epoch 4/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.5005 - loss: 14.5739
# Epoch 4: val_accuracy did not improve from 0.62080
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 425ms/step - accuracy: 0.5008 - loss: 14.5729 - val_accuracy: 0.5523 - val_loss: 14.2848 - learning_rate: 0.0050
# Epoch 5/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.6004 - loss: 14.1735
# Epoch 5: val_accuracy improved from 0.62080 to 0.72796, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 430ms/step - accuracy: 0.6003 - loss: 14.1724 - val_accuracy: 0.7280 - val_loss: 13.6743 - learning_rate: 0.0050
# Epoch 6/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.6071 - loss: 13.7463
# Epoch 6: val_accuracy improved from 0.72796 to 0.73367, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 431ms/step - accuracy: 0.6073 - loss: 13.7455 - val_accuracy: 0.7337 - val_loss: 13.2886 - learning_rate: 0.0050
# Epoch 7/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.6499 - loss: 13.4080
# Epoch 7: val_accuracy improved from 0.73367 to 0.75079, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 427ms/step - accuracy: 0.6500 - loss: 13.4072 - val_accuracy: 0.7508 - val_loss: 12.9810 - learning_rate: 0.0050
# Epoch 8/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.6723 - loss: 13.0772
# Epoch 8: val_accuracy did not improve from 0.75079
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 53s 432ms/step - accuracy: 0.6723 - loss: 13.0764 - val_accuracy: 0.6982 - val_loss: 12.8017 - learning_rate: 0.0050
# Epoch 9/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6861 - loss: 12.7519
# Epoch 9: val_accuracy improved from 0.75079 to 0.77362, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 53s 434ms/step - accuracy: 0.6863 - loss: 12.7509 - val_accuracy: 0.7736 - val_loss: 12.3547 - learning_rate: 0.0050
# Epoch 10/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.7291 - loss: 12.4232
# Epoch 10: val_accuracy did not improve from 0.77362
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 433ms/step - accuracy: 0.7291 - loss: 12.4223 - val_accuracy: 0.7362 - val_loss: 12.1881 - learning_rate: 0.0050
# Epoch 11/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.7467 - loss: 12.0894
# Epoch 11: val_accuracy did not improve from 0.77362
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 427ms/step - accuracy: 0.7467 - loss: 12.0890 - val_accuracy: 0.7324 - val_loss: 11.9480 - learning_rate: 0.0050
# Epoch 12/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.7797 - loss: 11.7602
# Epoch 12: val_accuracy did not improve from 0.77362
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 430ms/step - accuracy: 0.7796 - loss: 11.7600 - val_accuracy: 0.7584 - val_loss: 11.6028 - learning_rate: 0.0050
# Epoch 13/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.7598 - loss: 11.5490
# Epoch 13: val_accuracy improved from 0.77362 to 0.81230, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 426ms/step - accuracy: 0.7598 - loss: 11.5483 - val_accuracy: 0.8123 - val_loss: 11.2435 - learning_rate: 0.0050
# Epoch 14/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.7895 - loss: 11.2531
# Epoch 14: val_accuracy did not improve from 0.81230
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 428ms/step - accuracy: 0.7896 - loss: 11.2525 - val_accuracy: 0.7964 - val_loss: 11.0309 - learning_rate: 0.0050
# Epoch 15/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.7838 - loss: 11.0040
# Epoch 15: val_accuracy did not improve from 0.81230
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 427ms/step - accuracy: 0.7839 - loss: 11.0034 - val_accuracy: 0.8015 - val_loss: 10.7814 - learning_rate: 0.0050
# Epoch 16/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.8169 - loss: 10.7046
# Epoch 16: val_accuracy did not improve from 0.81230
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 427ms/step - accuracy: 0.8169 - loss: 10.7042 - val_accuracy: 0.8079 - val_loss: 10.5556 - learning_rate: 0.0050
# Epoch 17/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.8186 - loss: 10.4904
# Epoch 17: val_accuracy did not improve from 0.81230
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 428ms/step - accuracy: 0.8187 - loss: 10.4897 - val_accuracy: 0.7863 - val_loss: 10.3708 - learning_rate: 0.0050
# Epoch 18/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.8265 - loss: 10.2143
# Epoch 18: val_accuracy improved from 0.81230 to 0.83196, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 432ms/step - accuracy: 0.8264 - loss: 10.2141 - val_accuracy: 0.8320 - val_loss: 10.0443 - learning_rate: 0.0050
# Epoch 19/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.8255 - loss: 10.0284
# Epoch 19: val_accuracy did not improve from 0.83196
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 425ms/step - accuracy: 0.8255 - loss: 10.0277 - val_accuracy: 0.8022 - val_loss: 9.9016 - learning_rate: 0.0050
# Epoch 20/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.8533 - loss: 9.7111
# Epoch 20: val_accuracy improved from 0.83196 to 0.83576, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 430ms/step - accuracy: 0.8532 - loss: 9.7110 - val_accuracy: 0.8358 - val_loss: 9.6071 - learning_rate: 0.0050
# Epoch 21/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.8319 - loss: 9.5504
# Epoch 21: val_accuracy did not improve from 0.83576
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 426ms/step - accuracy: 0.8319 - loss: 9.5498 - val_accuracy: 0.8288 - val_loss: 9.4135 - learning_rate: 0.0050
# Epoch 22/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.8534 - loss: 9.2992
# Epoch 22: val_accuracy did not improve from 0.83576
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 426ms/step - accuracy: 0.8533 - loss: 9.2991 - val_accuracy: 0.8205 - val_loss: 9.2539 - learning_rate: 0.0050
# Epoch 23/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.8433 - loss: 9.1176
# Epoch 23: val_accuracy did not improve from 0.83576
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 428ms/step - accuracy: 0.8434 - loss: 9.1171 - val_accuracy: 0.8282 - val_loss: 9.0294 - learning_rate: 0.0050
# Epoch 24/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.8579 - loss: 8.8932
# Epoch 24: val_accuracy did not improve from 0.83576
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 425ms/step - accuracy: 0.8579 - loss: 8.8928 - val_accuracy: 0.8345 - val_loss: 8.8370 - learning_rate: 0.0050
# Epoch 25/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.8564 - loss: 8.7118
# Epoch 25: val_accuracy did not improve from 0.83576
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 429ms/step - accuracy: 0.8564 - loss: 8.7114 - val_accuracy: 0.8339 - val_loss: 8.6325 - learning_rate: 0.0050
# Epoch 26/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.8771 - loss: 8.4734
# Epoch 26: val_accuracy did not improve from 0.83576
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 431ms/step - accuracy: 0.8770 - loss: 8.4730 - val_accuracy: 0.8250 - val_loss: 8.4998 - learning_rate: 0.0050
# Epoch 27/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.8733 - loss: 8.2876
# Epoch 27: val_accuracy improved from 0.83576 to 0.84781, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 430ms/step - accuracy: 0.8733 - loss: 8.2875 - val_accuracy: 0.8478 - val_loss: 8.2320 - learning_rate: 0.0050
# Epoch 28/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.8862 - loss: 8.0986
# Epoch 28: val_accuracy improved from 0.84781 to 0.84845, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 433ms/step - accuracy: 0.8862 - loss: 8.0981 - val_accuracy: 0.8484 - val_loss: 8.0855 - learning_rate: 0.0050
# Epoch 29/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.8804 - loss: 7.9265
# Epoch 29: val_accuracy did not improve from 0.84845
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 429ms/step - accuracy: 0.8804 - loss: 7.9261 - val_accuracy: 0.8389 - val_loss: 7.9348 - learning_rate: 0.0050
# Epoch 30/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.8693 - loss: 7.7894
# Epoch 30: val_accuracy did not improve from 0.84845
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 426ms/step - accuracy: 0.8694 - loss: 7.7888 - val_accuracy: 0.8282 - val_loss: 7.8108 - learning_rate: 0.0050
# Epoch 31/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.8801 - loss: 7.6046
# Epoch 31: val_accuracy improved from 0.84845 to 0.85859, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 425ms/step - accuracy: 0.8801 - loss: 7.6040 - val_accuracy: 0.8586 - val_loss: 7.5463 - learning_rate: 0.0050
# Epoch 32/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.8985 - loss: 7.3940
# Epoch 32: val_accuracy did not improve from 0.85859
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 429ms/step - accuracy: 0.8985 - loss: 7.3936 - val_accuracy: 0.8402 - val_loss: 7.4717 - learning_rate: 0.0050
# Epoch 33/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.8929 - loss: 7.2272
# Epoch 33: val_accuracy improved from 0.85859 to 0.86557, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 430ms/step - accuracy: 0.8929 - loss: 7.2270 - val_accuracy: 0.8656 - val_loss: 7.2284 - learning_rate: 0.0050
# Epoch 34/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.8895 - loss: 7.0745
# Epoch 34: val_accuracy did not improve from 0.86557
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 431ms/step - accuracy: 0.8896 - loss: 7.0742 - val_accuracy: 0.8523 - val_loss: 7.1520 - learning_rate: 0.0050
# Epoch 35/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.8956 - loss: 6.9313
# Epoch 35: val_accuracy did not improve from 0.86557
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 429ms/step - accuracy: 0.8956 - loss: 6.9307 - val_accuracy: 0.8339 - val_loss: 7.0569 - learning_rate: 0.0050
# Epoch 36/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.9045 - loss: 6.7458
# Epoch 36: val_accuracy did not improve from 0.86557
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 432ms/step - accuracy: 0.9045 - loss: 6.7456 - val_accuracy: 0.8503 - val_loss: 6.8416 - learning_rate: 0.0050
# Epoch 37/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9213 - loss: 6.5675
# Epoch 37: val_accuracy did not improve from 0.86557
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 425ms/step - accuracy: 0.9213 - loss: 6.5675 - val_accuracy: 0.8567 - val_loss: 6.6680 - learning_rate: 0.0050
# Epoch 38/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.9277 - loss: 6.4305
# Epoch 38: val_accuracy did not improve from 0.86557
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 429ms/step - accuracy: 0.9276 - loss: 6.4303 - val_accuracy: 0.8542 - val_loss: 6.5290 - learning_rate: 0.0050
# Epoch 39/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9179 - loss: 6.2883
# Epoch 39: val_accuracy did not improve from 0.86557
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 51s 423ms/step - accuracy: 0.9179 - loss: 6.2882 - val_accuracy: 0.8643 - val_loss: 6.3632 - learning_rate: 0.0050
# Epoch 40/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.9170 - loss: 6.1574
# Epoch 40: val_accuracy did not improve from 0.86557
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 426ms/step - accuracy: 0.9170 - loss: 6.1570 - val_accuracy: 0.8554 - val_loss: 6.2789 - learning_rate: 0.0050
# Epoch 41/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.8979 - loss: 6.0574
# Epoch 41: val_accuracy improved from 0.86557 to 0.86684, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 431ms/step - accuracy: 0.8980 - loss: 6.0570 - val_accuracy: 0.8668 - val_loss: 6.1001 - learning_rate: 0.0050
# Epoch 42/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.9273 - loss: 5.8775
# Epoch 42: val_accuracy did not improve from 0.86684
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 53s 433ms/step - accuracy: 0.9273 - loss: 5.8773 - val_accuracy: 0.8573 - val_loss: 6.0271 - learning_rate: 0.0050
# Epoch 43/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.9248 - loss: 5.7484
# Epoch 43: val_accuracy did not improve from 0.86684
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 427ms/step - accuracy: 0.9248 - loss: 5.7482 - val_accuracy: 0.8510 - val_loss: 5.9293 - learning_rate: 0.0050
# Epoch 44/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.9080 - loss: 5.6705
# Epoch 44: val_accuracy did not improve from 0.86684
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 427ms/step - accuracy: 0.9081 - loss: 5.6699 - val_accuracy: 0.8643 - val_loss: 5.7652 - learning_rate: 0.0050
# Epoch 45/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9274 - loss: 5.4894
# Epoch 45: val_accuracy did not improve from 0.86684
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 51s 423ms/step - accuracy: 0.9274 - loss: 5.4892 - val_accuracy: 0.8421 - val_loss: 5.6909 - learning_rate: 0.0050
# Epoch 46/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9343 - loss: 5.3774
# Epoch 46: val_accuracy did not improve from 0.86684
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 426ms/step - accuracy: 0.9342 - loss: 5.3772 - val_accuracy: 0.8592 - val_loss: 5.5133 - learning_rate: 0.0050
# Epoch 47/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9408 - loss: 5.2424
# Epoch 47: val_accuracy improved from 0.86684 to 0.87001, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 425ms/step - accuracy: 0.9408 - loss: 5.2422 - val_accuracy: 0.8700 - val_loss: 5.3859 - learning_rate: 0.0050
# Epoch 48/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9400 - loss: 5.1308
# Epoch 48: val_accuracy did not improve from 0.87001
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 51s 422ms/step - accuracy: 0.9400 - loss: 5.1306 - val_accuracy: 0.8662 - val_loss: 5.3059 - learning_rate: 0.0050
# Epoch 49/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.9334 - loss: 5.0404
# Epoch 49: val_accuracy did not improve from 0.87001
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 424ms/step - accuracy: 0.9335 - loss: 5.0400 - val_accuracy: 0.8675 - val_loss: 5.1935 - learning_rate: 0.0050
# Epoch 50/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.9437 - loss: 4.9126
# Epoch 50: val_accuracy did not improve from 0.87001
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 430ms/step - accuracy: 0.9437 - loss: 4.9123 - val_accuracy: 0.8516 - val_loss: 5.1427 - learning_rate: 0.0050
# Epoch 51/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9314 - loss: 4.8123
# Epoch 51: val_accuracy did not improve from 0.87001
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 81s 425ms/step - accuracy: 0.9314 - loss: 4.8120 - val_accuracy: 0.8440 - val_loss: 5.0283 - learning_rate: 0.0050
# Epoch 52/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.9443 - loss: 4.6925
# Epoch 52: val_accuracy did not improve from 0.87001
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 426ms/step - accuracy: 0.9443 - loss: 4.6923 - val_accuracy: 0.8643 - val_loss: 4.9074 - learning_rate: 0.0050
# Epoch 53/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.9397 - loss: 4.5975
# Epoch 53: val_accuracy did not improve from 0.87001
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 424ms/step - accuracy: 0.9398 - loss: 4.5972 - val_accuracy: 0.8656 - val_loss: 4.8303 - learning_rate: 0.0050
# Epoch 54/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.9479 - loss: 4.4900
# Epoch 54: val_accuracy did not improve from 0.87001
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 429ms/step - accuracy: 0.9479 - loss: 4.4898 - val_accuracy: 0.8637 - val_loss: 4.7328 - learning_rate: 0.0050
# Epoch 55/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9505 - loss: 4.3836
# Epoch 55: val_accuracy did not improve from 0.87001
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.0004999999888241291.
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 51s 422ms/step - accuracy: 0.9505 - loss: 4.3835 - val_accuracy: 0.8656 - val_loss: 4.5918 - learning_rate: 0.0050
# Epoch 56/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.9719 - loss: 4.2743
# Epoch 56: val_accuracy improved from 0.87001 to 0.87254, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 426ms/step - accuracy: 0.9719 - loss: 4.2742 - val_accuracy: 0.8725 - val_loss: 4.5766 - learning_rate: 5.0000e-04
# Epoch 57/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.9646 - loss: 4.2575
# Epoch 57: val_accuracy improved from 0.87254 to 0.87381, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 426ms/step - accuracy: 0.9646 - loss: 4.2575 - val_accuracy: 0.8738 - val_loss: 4.5749 - learning_rate: 5.0000e-04
# Epoch 58/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.9709 - loss: 4.2446
# Epoch 58: val_accuracy improved from 0.87381 to 0.87445, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 431ms/step - accuracy: 0.9709 - loss: 4.2446 - val_accuracy: 0.8744 - val_loss: 4.5698 - learning_rate: 5.0000e-04
# Epoch 59/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9702 - loss: 4.2331
# Epoch 59: val_accuracy did not improve from 0.87445
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 425ms/step - accuracy: 0.9701 - loss: 4.2332 - val_accuracy: 0.8706 - val_loss: 4.5587 - learning_rate: 5.0000e-04
# Epoch 60/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.9760 - loss: 4.2146
# Epoch 60: val_accuracy did not improve from 0.87445
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 51s 423ms/step - accuracy: 0.9760 - loss: 4.2147 - val_accuracy: 0.8738 - val_loss: 4.5505 - learning_rate: 5.0000e-04
# Epoch 61/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.9770 - loss: 4.2018
# Epoch 61: val_accuracy did not improve from 0.87445
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 424ms/step - accuracy: 0.9770 - loss: 4.2018 - val_accuracy: 0.8713 - val_loss: 4.5400 - learning_rate: 5.0000e-04
# Epoch 62/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9715 - loss: 4.2001
# Epoch 62: val_accuracy did not improve from 0.87445
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 426ms/step - accuracy: 0.9715 - loss: 4.2000 - val_accuracy: 0.8732 - val_loss: 4.5367 - learning_rate: 5.0000e-04
# Epoch 63/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9722 - loss: 4.1966
# Epoch 63: val_accuracy did not improve from 0.87445
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 51s 423ms/step - accuracy: 0.9722 - loss: 4.1966 - val_accuracy: 0.8732 - val_loss: 4.5240 - learning_rate: 5.0000e-04
# Epoch 64/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9705 - loss: 4.1857
# Epoch 64: val_accuracy did not improve from 0.87445
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 424ms/step - accuracy: 0.9705 - loss: 4.1857 - val_accuracy: 0.8732 - val_loss: 4.5196 - learning_rate: 5.0000e-04
# Epoch 65/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.9738 - loss: 4.1684
# Epoch 65: val_accuracy improved from 0.87445 to 0.87508, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 427ms/step - accuracy: 0.9738 - loss: 4.1684 - val_accuracy: 0.8751 - val_loss: 4.5160 - learning_rate: 5.0000e-04
# Epoch 66/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9703 - loss: 4.1650
# Epoch 66: val_accuracy did not improve from 0.87508
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 425ms/step - accuracy: 0.9703 - loss: 4.1649 - val_accuracy: 0.8744 - val_loss: 4.5021 - learning_rate: 5.0000e-04
# Epoch 67/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.9649 - loss: 4.1670
# Epoch 67: val_accuracy did not improve from 0.87508
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 425ms/step - accuracy: 0.9649 - loss: 4.1669 - val_accuracy: 0.8732 - val_loss: 4.4925 - learning_rate: 5.0000e-04
# Epoch 68/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.9725 - loss: 4.1408
# Epoch 68: val_accuracy improved from 0.87508 to 0.87635, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 428ms/step - accuracy: 0.9725 - loss: 4.1409 - val_accuracy: 0.8763 - val_loss: 4.4864 - learning_rate: 5.0000e-04
# Epoch 69/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.9724 - loss: 4.1402
# Epoch 69: val_accuracy did not improve from 0.87635
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 424ms/step - accuracy: 0.9725 - loss: 4.1401 - val_accuracy: 0.8751 - val_loss: 4.4787 - learning_rate: 5.0000e-04
# Epoch 70/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.9683 - loss: 4.1427
# Epoch 70: val_accuracy did not improve from 0.87635
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 427ms/step - accuracy: 0.9683 - loss: 4.1425 - val_accuracy: 0.8763 - val_loss: 4.4759 - learning_rate: 5.0000e-04
# Epoch 71/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.9726 - loss: 4.1134
# Epoch 71: val_accuracy did not improve from 0.87635
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 51s 421ms/step - accuracy: 0.9727 - loss: 4.1134 - val_accuracy: 0.8725 - val_loss: 4.4611 - learning_rate: 5.0000e-04
# Epoch 72/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9716 - loss: 4.1161
# Epoch 72: val_accuracy did not improve from 0.87635
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 425ms/step - accuracy: 0.9716 - loss: 4.1160 - val_accuracy: 0.8738 - val_loss: 4.4505 - learning_rate: 5.0000e-04
# Epoch 73/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9763 - loss: 4.0891
# Epoch 73: val_accuracy improved from 0.87635 to 0.87698, saving model to ./output/bestmodel.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 429ms/step - accuracy: 0.9763 - loss: 4.0891 - val_accuracy: 0.8770 - val_loss: 4.4525 - learning_rate: 5.0000e-04
# Epoch 74/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9700 - loss: 4.0901
# Epoch 74: val_accuracy did not improve from 0.87698
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 426ms/step - accuracy: 0.9701 - loss: 4.0901 - val_accuracy: 0.8732 - val_loss: 4.4309 - learning_rate: 5.0000e-04
# Epoch 75/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.9752 - loss: 4.0699
# Epoch 75: val_accuracy did not improve from 0.87698
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 428ms/step - accuracy: 0.9751 - loss: 4.0700 - val_accuracy: 0.8738 - val_loss: 4.4223 - learning_rate: 5.0000e-04
# Epoch 76/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.9749 - loss: 4.0712
# Epoch 76: val_accuracy did not improve from 0.87698
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 429ms/step - accuracy: 0.9749 - loss: 4.0712 - val_accuracy: 0.8732 - val_loss: 4.4182 - learning_rate: 5.0000e-04
# Epoch 77/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.9755 - loss: 4.0524
# Epoch 77: val_accuracy did not improve from 0.87698
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 51s 423ms/step - accuracy: 0.9755 - loss: 4.0525 - val_accuracy: 0.8751 - val_loss: 4.4061 - learning_rate: 5.0000e-04
# Epoch 78/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.9741 - loss: 4.0594
# Epoch 78: val_accuracy did not improve from 0.87698
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 426ms/step - accuracy: 0.9741 - loss: 4.0593 - val_accuracy: 0.8725 - val_loss: 4.3987 - learning_rate: 5.0000e-04
# Epoch 79/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9747 - loss: 4.0360
# Epoch 79: val_accuracy did not improve from 0.87698
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 51s 420ms/step - accuracy: 0.9747 - loss: 4.0361 - val_accuracy: 0.8744 - val_loss: 4.3952 - learning_rate: 5.0000e-04
# Epoch 80/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9729 - loss: 4.0350
# Epoch 80: val_accuracy did not improve from 0.87698
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 51s 423ms/step - accuracy: 0.9729 - loss: 4.0350 - val_accuracy: 0.8757 - val_loss: 4.3830 - learning_rate: 5.0000e-04
# Epoch 81/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9747 - loss: 4.0273
# Epoch 81: val_accuracy did not improve from 0.87698
#
# Epoch 81: ReduceLROnPlateau reducing learning rate to 4.9999996554106475e-05.
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 425ms/step - accuracy: 0.9747 - loss: 4.0272 - val_accuracy: 0.8751 - val_loss: 4.3818 - learning_rate: 5.0000e-04
# Epoch 82/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.9805 - loss: 3.9998
# Epoch 82: val_accuracy did not improve from 0.87698
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 52s 427ms/step - accuracy: 0.9805 - loss: 3.9999 - val_accuracy: 0.8751 - val_loss: 4.3789 - learning_rate: 5.0000e-05
# Epoch 83/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.9745 - loss: 4.0215
# Epoch 83: val_accuracy did not improve from 0.87698
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 82s 427ms/step - accuracy: 0.9745 - loss: 4.0214 - val_accuracy: 0.8751 - val_loss: 4.3778 - learning_rate: 5.0000e-05

# %%
#Test the model with the test set

model.evaluate(testdata)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.9057 - loss: 4.2458
# [4.377779006958008, 0.8750792741775513]

# %%
# Visualize the model

plt.plot(history.history['accuracy'], marker='o')
plt.plot(history.history['val_accuracy'], marker='o')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'], marker='o')
plt.plot(history.history['val_loss'], marker='o')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# Prediksi label kelas menggunakan model terhadap data uji
predictions = model.predict(testdata)
predicted_classes = np.argmax(predictions, axis=1)

# Ambil label sebenarnya dari data uji
true_classes = testdata.labels

# Dapatkan nama kelas
class_labels = list(testdata.class_indices.keys())

# Buat classification matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Print classification matrix
print("Classification Matrix:")
print(cm)

# Print classification report
print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))
# Out:
#  2/50 ━━━━━━━━━━━━━━━━━━━━ 7s 150ms/step
# W0000 00:00:1718278975.367635     107 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 145ms/step
# Classification Matrix:
# [[169   3   1   5   4]
#  [  4 338   3   3  27]
#  [  4   1 309  18  16]
#  [ 11   1  35 232  11]
#  [  3  18  26   9 326]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         bath       0.88      0.93      0.91       182
#          bed       0.94      0.90      0.92       375
#          din       0.83      0.89      0.86       348
#      kitchen       0.87      0.80      0.83       290
#       living       0.85      0.85      0.85       382
#
#     accuracy                           0.87      1577
#    macro avg       0.87      0.87      0.87      1577
# weighted avg       0.87      0.87      0.87      1577
# W0000 00:00:1718278982.462967     104 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update

# %% [markdown]
# Accuracy adalah rasio dari jumlah prediksi yang benar (true predictions) dibagi dengan jumlah total instance dalam dataset.

# %% [markdown]
# Precision mengukur seberapa akurat model dalam memprediksi kelas positif. Ini dihitung sebagai rasio dari true positive (TP) dibagi oleh jumlah true positive dan false positive (FP).

# %% [markdown]
#  Recall mengukur seberapa baik model dalam menemukan semua instance yang benar dari kelas yang diinginkan. Ini dihitung sebagai rasio dari true positive (TP) dibagi oleh jumlah true positive dan false negative (FN).

# %% [markdown]
# F1-score adalah rata-rata harmonik dari precision dan recall. Ini memberikan keseimbangan antara precision dan recall.

# %% [markdown]
# ### Mencoba dengan dataset lain

# %% [markdown]
# ### Dataset source: https://www.kaggle.com/datasets/annielu21/house-rooms

# %%
import os
import shutil

# Menggunakan direktori yang dapat ditulis
img_path2 = '/kaggle/input/house-rooms/room-dataset'
input_dir = 'images'
output_dir2 = 'new_output'

# Membuat folder output jika belum ada
os.makedirs(output_dir2, exist_ok=True)

# Membuat Folder Kategori
categories = ['bath', 'bed', 'din', 'kitchen', 'living']
for category in categories:
    category_dir = os.path.join(output_dir2, category)
    os.makedirs(category_dir, exist_ok=True)

# %%
folder_mapping = {
    'bathroom': 'bath',
    'bedroom': 'bed',
    'dining': 'din',
    'kitchen': 'kitchen',
    'living': 'living'
}

# %%
# Memindahkan file ke folder yang dipilih
for root, dirs, files in os.walk(img_path2):
    for file in files:
        category = os.path.basename(root)
        if category in folder_mapping:
            source_file = os.path.join(root, file)
            destination_dir = os.path.join(output_dir2, folder_mapping[category])
            shutil.copy(source_file, destination_dir)

# %%
for category in categories:
    category_dir = os.path.join(output_dir2, category)
    num_files = len(os.listdir(category_dir))
    print(f"Total {category} files: {num_files}")

# %%
# Define the ImageDataGenerator for the new dataset
new_datagen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=preprocess_input
)

# Create a generator for the new dataset
new_generator = new_datagen.flow_from_directory(
    directory=output_dir2,
    classes=['bath', 'bed', 'din', 'kitchen', 'living'],
    target_size=(224,224), 
    color_mode="rgb", 
    class_mode='categorical',
    batch_size=32,  # Specify the batch size
    shuffle=False  # Do not shuffle the data for testing
)

# %%
def create_model():

    np.random.seed(42)

    model = Sequential()
    model.add(Input(shape=(224,224,3)))
    model.add(base_model)
    model.add(Flatten())
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(len(categories), activation='softmax'))
    
    
    optimizer = SGD(learning_rate=0.005)
    
    model.compile(
      optimizer=optimizer,
      loss='categorical_crossentropy',
      metrics=['accuracy'])
    
    return model

model2 = create_model()

# %%
model2.summary()

# %%
model2.load_weights('/kaggle/working/output/bestmodel.keras')

# %%
model2.evaluate(new_generator)

# %% [markdown]
# ### Didapatkan akurasi 80% untuk dataset yang lain
